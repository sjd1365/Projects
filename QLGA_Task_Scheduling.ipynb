# %% [markdown]
# <a href="https://colab.research.google.com/github/sjd1365/Projects/blob/main/QLGA_Task_Scheduling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##📦 instance_generator.py

# %%
import numpy as np
import random

class CMgInstance:
    def __init__(self, n_tasks=10, n_providers=3):
        self.n_tasks = n_tasks
        self.n_providers = n_providers

        # ---------- GENERATE STRUCTURE ----------
        self.subtasks_per_task = [random.randint(2,5) for _ in range(n_tasks)]
        self.machines_per_provider = [random.randint(2,5) for _ in range(n_providers)]

        # ---------- ARRIVAL TIMES ----------
        self.arrival_time = np.random.randint(0,200, size=n_tasks)

        # ---------- PROCESSING TIMES ----------
        # P[i][j][k][r]
        self.processing_time = self.generate_processing_times()

        # ---------- LOGISTICS ----------
        self.TSS = np.random.randint(5,30,(n_providers,n_providers))  # SP to SP
        self.TSC = np.random.randint(5,50,(n_providers,n_tasks))      # SP to customer

    # -----------------------------------------
    def generate_processing_times(self):
        P = {}
        for i in range(self.n_tasks):
            P[i] = {}
            for j in range(self.subtasks_per_task[i]):
                P[i][j] = {}
                for k in range(self.n_providers):
                    P[i][j][k] = {}
                    for r in range(self.machines_per_provider[k]):
                        P[i][j][k][r] = random.randint(10,100)
        return P

# ----------- helper to create benchmark sizes ----------
def generate_instance(size="small"):

    if size == "small":
        return CMgInstance(n_tasks=10, n_providers=3)
    elif size == "medium":
        return CMgInstance(n_tasks=20, n_providers=5)
    else:
        return CMgInstance(n_tasks=35, n_providers=8)

# %% [markdown]
# ##File.Test

# %%
module_content = """import numpy as np
import random

class CMgInstance:
    def __init__(self, n_tasks=10, n_providers=3):
        self.n_tasks = n_tasks
        self.n_providers = n_providers

        # ---------- GENERATE STRUCTURE ----------
        self.subtasks_per_task = [random.randint(2,5) for _ in range(n_tasks)]
        self.machines_per_provider = [random.randint(2,5) for _ in range(n_providers)]

        # ---------- ARRIVAL TIMES ----------
        self.arrival_time = np.random.randint(0,200, size=n_tasks)

        # ---------- PROCESSING TIMES ----------
        # P[i][j][k][r]
        self.processing_time = self.generate_processing_times()

        # ---------- LOGISTICS ----------
        self.TSS = np.random.randint(5,30,(n_providers,n_providers))  # SP to SP
        self.TSC = np.random.randint(5,50,(n_providers,n_tasks))      # SP to customer

    # -----------------------------------------
    def generate_processing_times(self):
        P = {}
        for i in range(self.n_tasks):
            P[i] = {}
            for j in range(self.subtasks_per_task[i]):
                P[i][j] = {}
                for k in range(self.n_providers):
                    P[i][j][k] = {}
                    for r in range(self.machines_per_provider[k]):
                        P[i][j][k][r] = random.randint(10,100)
        return P

# ----------- helper to create benchmark sizes ----------
def generate_instance(size="small"):

    if size == "small":
        return CMgInstance(n_tasks=10, n_providers=3)
    elif size == "medium":
        return CMgInstance(n_tasks=20, n_providers=5)
    else:
        return CMgInstance(n_tasks=35, n_providers=8)
"""

with open('instance_generator.py', 'w') as f:
    f.write(module_content)

from instance_generator import generate_instance

inst = generate_instance("small")

print("Tasks:", inst.n_tasks)
print("Providers:", inst.n_providers)
print("Subtasks per task:", inst.subtasks_per_task)
print("Arrival time:", inst.arrival_time)
# Out:
# Tasks: 10
# Providers: 3
# Subtasks per task: [3, 2, 5, 2, 3, 5, 5, 5, 5, 2]
# Arrival time: [138 119  70  51 167  34 137 141  69  83]

# %% [markdown]
# ##📦 scheduler_simulator.py

# %%
import numpy as np
from collections import defaultdict

class Scheduler:
    def __init__(self, instance):
        self.inst = instance

    # --------------------------------------------------
    # انتخاب بهترین ماشین برای یک عملیات
    # --------------------------------------------------
    def select_best_machine(self, task, subtask, ready_time):
        best_finish = 1e18
        best_choice = None

        for k in range(self.inst.n_providers):
            for r in range(self.inst.machines_per_provider[k]):

                proc_time = self.inst.processing_time[task][subtask][k][r]
                finish_time = ready_time + proc_time

                if finish_time < best_finish:
                    best_finish = finish_time
                    best_choice = (k,r,proc_time)

        return best_choice  # provider, machine, processing_time

    # --------------------------------------------------
    # DECODE chromosome → schedule → makespan
    # --------------------------------------------------
    def evaluate(self, chromosome):

        # زمان آزاد شدن ماشین‌ها
        machine_available = defaultdict(int)

        # پایان آخرین subtask هر task
        task_last_finish = defaultdict(int)

        # شماره subtask بعدی که باید اجرا شود
        next_subtask_index = defaultdict(int)

        # شروع کار = arrival time
        for t in range(self.inst.n_tasks):
            task_last_finish[t] = self.inst.arrival_time[t]

        # ----------------------------------------------
        for gene in chromosome:
            task = gene

            subtask = next_subtask_index[task]

            # اگر همه subtasks انجام شده → رد کن
            if subtask >= self.inst.subtasks_per_task[task]:
                continue

            ready_time = task_last_finish[task]

            # انتخاب بهترین ماشین
            provider, machine, proc_time = self.select_best_machine(
                task, subtask, ready_time
            )

            machine_key = (provider, machine)
            start_time = max(machine_available[machine_key], ready_time)
            finish_time = start_time + proc_time

            # آپدیت وضعیت‌ها
            machine_available[machine_key] = finish_time
            task_last_finish[task] = finish_time
            next_subtask_index[task] += 1

        # ----------------------------------------------
        # makespan = آخرین پایان
        makespan = max(task_last_finish.values())
        return makespan

# %% [markdown]
# ##Test

# %%
import random

# Create scheduler_simulator.py
module_content_scheduler = """import numpy as np
from collections import defaultdict

class Scheduler:
    def __init__(self, instance):
        self.inst = instance

    # --------------------------------------------------
    # انتخاب بهترین ماشین برای یک عملیات
    # --------------------------------------------------
    def select_best_machine(self, task, subtask, ready_time):
        best_finish = 1e18
        best_choice = None

        for k in range(self.inst.n_providers):
            for r in range(self.inst.machines_per_provider[k]):

                proc_time = self.inst.processing_time[task][subtask][k][r]
                finish_time = ready_time + proc_time

                if finish_time < best_finish:
                    best_finish = finish_time
                    best_choice = (k,r,proc_time)

        return best_choice  # provider, machine, processing_time

    # --------------------------------------------------
    # DECODE chromosome → schedule → makespan
    # --------------------------------------------------
    def evaluate(self, chromosome):

        # زمان آزاد شدن ماشین‌ها
        machine_available = defaultdict(int)

        # پایان آخرین subtask هر task
        task_last_finish = defaultdict(int)

        # شماره subtask بعدی که باید اجرا شود
        next_subtask_index = defaultdict(int)

        # شروع کار = arrival time
        for t in range(self.inst.n_tasks):
            task_last_finish[t] = self.inst.arrival_time[t]

        # ----------------------------------------------
        for gene in chromosome:
            task = gene

            subtask = next_subtask_index[task]

            # اگر همه subtasks انجام شده → رد کن
            if subtask >= self.inst.subtasks_per_task[task]:
                continue

            ready_time = task_last_finish[task]

            # انتخاب بهترین ماشین
            provider, machine, proc_time = self.select_best_machine(
                task, subtask, ready_time
            )

            machine_key = (provider, machine)
            start_time = max(machine_available[machine_key], ready_time)
            finish_time = start_time + proc_time

            # آپدیت وضعیت‌ها
            machine_available[machine_key] = finish_time
            task_last_finish[task] = finish_time
            next_subtask_index[task] += 1

        # ----------------------------------------------
        # makespan = آخرین پایان
        makespan = max(task_last_finish.values())
        return makespan"""

with open('scheduler_simulator.py', 'w') as f:
    f.write(module_content_scheduler)

from instance_generator import generate_instance
from scheduler_simulator import Scheduler

inst = generate_instance("small")
scheduler = Scheduler(inst)

# ساخت یک chromosome تصادفی
chromosome = []
for t in range(inst.n_tasks):
    chromosome += [t] * inst.subtasks_per_task[t]

random.shuffle(chromosome)

makespan = scheduler.evaluate(chromosome)
print("Makespan:", makespan)
# Out:
# Makespan: 300

# %% [markdown]
# ##🧬 Step 3 — Genetic Algorithm Baseline

# %%
# Initialize population
# Repeat for generations:
#     Selection
#     Crossover
#     Mutation
#     Evaluation
#     Elitism
# Return best solution

# %% [markdown]
# ##📦 File operators.py

# %%
import random

# -----------------------------
# MUTATIONS
# -----------------------------
def swap_mutation(chrom):
    a, b = random.sample(range(len(chrom)), 2)
    chrom[a], chrom[b] = chrom[b], chrom[a]
    return chrom

def pairwise_swap(chrom):
    for i in range(0, len(chrom)-1, 2):
        if random.random() < 0.5:
            chrom[i], chrom[i+1] = chrom[i+1], chrom[i]
    return chrom

def inversion_mutation(chrom):
    a, b = sorted(random.sample(range(len(chrom)), 2))
    chrom[a:b] = reversed(chrom[a:b])
    return chrom

# -----------------------------
# CROSSOVERS
# -----------------------------
def one_point_crossover(p1, p2):
    cut = random.randint(1, len(p1)-2)
    c1 = p1[:cut] + p2[cut:]
    c2 = p2[:cut] + p1[cut:]
    return c1, c2

def two_point_crossover(p1, p2):
    a, b = sorted(random.sample(range(len(p1)), 2))
    c1 = p1[:a] + p2[a:b] + p1[b:]
    c2 = p2[:a] + p1[a:b] + p2[b:]
    return c1, c2

def uniform_crossover(p1, p2):
    c1, c2 = [], []
    for g1, g2 in zip(p1, p2):
        if random.random() < 0.5:
            c1.append(g1); c2.append(g2)
        else:
            c1.append(g2); c2.append(g1)
    return c1, c2

# %% [markdown]
# ##📦 File ga_baseline.py

# %%
import random
import numpy as np
from scheduler_simulator import Scheduler

# Create operators.py
module_content_operators = """import random

# -----------------------------
# MUTATIONS
# -----------------------------
def swap_mutation(chrom):
    a, b = random.sample(range(len(chrom)), 2)
    chrom[a], chrom[b] = chrom[b], chrom[a]
    return chrom

def pairwise_swap(chrom):
    for i in range(0, len(chrom)-1, 2):
        if random.random() < 0.5:
            chrom[i], chrom[i+1] = chrom[i+1], chrom[i]
    return chrom

def inversion_mutation(chrom):
    a, b = sorted(random.sample(range(len(chrom)), 2))
    chrom[a:b] = reversed(chrom[a:b])
    return chrom

# -----------------------------
# CROSSOVERS
# -----------------------------
def one_point_crossover(p1, p2):
    cut = random.randint(1, len(p1)-2)
    c1 = p1[:cut] + p2[cut:]
    c2 = p2[:cut] + p1[cut:]
    return c1, c2

def two_point_crossover(p1, p2):
    a, b = sorted(random.sample(range(len(p1)), 2))
    c1 = p1[:a] + p2[a:b] + p1[b:]
    c2 = p2[:a] + p1[a:b] + p2[b:]
    return c1, c2

def uniform_crossover(p1, p2):
    c1, c2 = [], []
    for g1, g2 in zip(p1, p2):
        if random.random() < 0.5:
            c1.append(g1); c2.append(g2)
        else:
            c1.append(g2); c2.append(g1)
    return c1, c2"""

with open('operators.py', 'w') as f:
    f.write(module_content_operators)

from operators import *

class GeneticAlgorithm:
    def __init__(self, instance, pop_size=40, generations=60):
        self.inst = instance
        self.scheduler = Scheduler(instance)
        self.pop_size = pop_size
        self.generations = generations

        self.mutations = [swap_mutation, pairwise_swap, inversion_mutation]
        self.crossovers = [one_point_crossover, two_point_crossover, uniform_crossover]

    # ------------------------------------------
    def create_chromosome(self):
        chrom = []
        for t in range(self.inst.n_tasks):
            chrom += [t] * self.inst.subtasks_per_task[t]
        random.shuffle(chrom)
        return chrom

    # ------------------------------------------
    def init_population(self):
        return [self.create_chromosome() for _ in range(self.pop_size)]

    # ------------------------------------------
    def evaluate_population(self, pop):
        return [self.scheduler.evaluate(ind) for ind in pop]

    # ------------------------------------------
    def tournament_selection(self, pop, fitness, k=3):
        selected = random.sample(range(len(pop)), k)
        best = min(selected, key=lambda i: fitness[i])
        return pop[best]

    # ------------------------------------------
    def run(self):
        population = self.init_population()
        best_global = None
        best_fit = 1e18

        for gen in range(self.generations):
            fitness = self.evaluate_population(population)

            # elitism
            elite_idx = np.argmin(fitness)
            elite = population[elite_idx]

            if fitness[elite_idx] < best_fit:
                best_fit = fitness[elite_idx]
                best_global = elite

            new_pop = [elite]

            while len(new_pop) < self.pop_size:
                p1 = self.tournament_selection(population, fitness)
                p2 = self.tournament_selection(population, fitness)

                crossover = random.choice(self.crossovers)
                c1, c2 = crossover(p1.copy(), p2.copy())

                mutation = random.choice(self.mutations)
                c1 = mutation(c1)
                c2 = mutation(c2)

                new_pop += [c1, c2]

            population = new_pop[:self.pop_size]
            print(f"Gen {gen}  Best = {best_fit}")

        return best_global, best_fit

# %% [markdown]
# ##� Test GA

# %%
# module_content for instance_generator.py
module_content_instance = """import numpy as np
import random

class CMgInstance:
    def __init__(self, n_tasks=10, n_providers=3):
        self.n_tasks = n_tasks
        self.n_providers = n_providers

        # ---------- GENERATE STRUCTURE ----------
        self.subtasks_per_task = [random.randint(2,5) for _ in range(n_tasks)]
        self.machines_per_provider = [random.randint(2,5) for _ in range(n_providers)]

        # ---------- ARRIVAL TIMES ----------
        self.arrival_time = np.random.randint(0,200, size=n_tasks)

        # ---------- PROCESSING TIMES ----------
        # P[i][j][k][r]
        self.processing_time = self.generate_processing_times()

        # ---------- LOGISTICS ----------
        self.TSS = np.random.randint(5,30,(n_providers,n_providers))  # SP to SP
        self.TSC = np.random.randint(5,50,(n_providers,n_tasks))      # SP to customer

    # -----------------------------------------
    def generate_processing_times(self):
        P = {}
        for i in range(self.n_tasks):
            P[i] = {}
            for j in range(self.subtasks_per_task[i]):
                P[i][j] = {}
                for k in range(self.n_providers):
                    P[i][j][k] = {}
                    for r in range(self.machines_per_provider[k]):
                        P[i][j][k][r] = random.randint(10,100)
        return P

# ----------- helper to create benchmark sizes ----------
def generate_instance(size="small"):

    if size == "small":
        return CMgInstance(n_tasks=10, n_providers=3)
    elif size == "medium":
        return CMgInstance(n_tasks=20, n_providers=5)
    else:
        return CMgInstance(n_tasks=35, n_providers=8)
"""
with open('instance_generator.py', 'w') as f:
    f.write(module_content_instance)


# module_content for scheduler_simulator.py
module_content_scheduler = """import numpy as np
from collections import defaultdict

class Scheduler:
    def __init__(self, instance):
        self.inst = instance

    # --------------------------------------------------
    # انتخاب بهترین ماشین برای یک عملیات
    # --------------------------------------------------
    def select_best_machine(self, task, subtask, ready_time):
        best_finish = 1e18
        best_choice = None

        for k in range(self.inst.n_providers):
            for r in range(self.inst.machines_per_provider[k]):

                proc_time = self.inst.processing_time[task][subtask][k][r]
                finish_time = ready_time + proc_time

                if finish_time < best_finish:
                    best_finish = finish_time
                    best_choice = (k,r,proc_time)

        return best_choice  # provider, machine, processing_time

    # --------------------------------------------------
    # DECODE chromosome → schedule → makespan
    # --------------------------------------------------
    def evaluate(self, chromosome):

        # زمان آزاد شدن ماشین‌ها
        machine_available = defaultdict(int)

        # پایان آخرین subtask هر task
        task_last_finish = defaultdict(int)

        # شماره subtask بعدی که باید اجرا شود
        next_subtask_index = defaultdict(int)

        # شروع کار = arrival time
        for t in range(self.inst.n_tasks):
            task_last_finish[t] = self.inst.arrival_time[t]

        # ----------------------------------------------
        for gene in chromosome:
            task = gene

            subtask = next_subtask_index[task]

            # اگر همه subtasks انجام شده → رد کن
            if subtask >= self.inst.subtasks_per_task[task]:
                continue

            ready_time = task_last_finish[task]

            # انتخاب بهترین ماشین
            provider, machine, proc_time = self.select_best_machine(
                task, subtask, ready_time
            )

            machine_key = (provider, machine)
            start_time = max(machine_available[machine_key], ready_time)
            finish_time = start_time + proc_time

            # آپدیت وضعیت‌ها
            machine_available[machine_key] = finish_time
            task_last_finish[task] = finish_time
            next_subtask_index[task] += 1

        # ----------------------------------------------
        # makespan = آخرین پایان
        makespan = max(task_last_finish.values())
        return makespan
"""
with open('scheduler_simulator.py', 'w') as f:
    f.write(module_content_scheduler)


# module_content for operators.py
module_content_operators = """import random

# -----------------------------
# MUTATIONS
# -----------------------------
def swap_mutation(chrom):
    a, b = random.sample(range(len(chrom)), 2)
    chrom[a], chrom[b] = chrom[b], chrom[a]
    return chrom

def pairwise_swap(chrom):
    for i in range(0, len(chrom)-1, 2):
        if random.random() < 0.5:
            chrom[i], chrom[i+1] = chrom[i+1], chrom[i]
    return chrom

def inversion_mutation(chrom):
    a, b = sorted(random.sample(range(len(chrom)), 2))
    chrom[a:b] = reversed(chrom[a:b])
    return chrom

# -----------------------------
# CROSSOVERS
# -----------------------------
def one_point_crossover(p1, p2):
    cut = random.randint(1, len(p1)-2)
    c1 = p1[:cut] + p2[cut:]
    c2 = p2[:cut] + p1[cut:]
    return c1, c2

def two_point_crossover(p1, p2):
    a, b = sorted(random.sample(range(len(p1)), 2))
    c1 = p1[:a] + p2[a:b] + p1[b:]
    c2 = p2[:a] + p1[a:b] + p2[b:]
    return c1, c2

def uniform_crossover(p1, p2):
    c1, c2 = [], []
    for g1, g2 in zip(p1, p2):
        if random.random() < 0.5:
            c1.append(g1); c2.append(g2)
        else:
            c1.append(g2); c2.append(g1)
    return c1, c2
"""
with open('operators.py', 'w') as f:
    f.write(module_content_operators)


# module_content for ga_baseline.py
# Note: This is an adjusted version of the content of cell 1nl8TvXV4wDZ
# without the internal 'operators.py' creation logic, as that's handled above.
module_content_ga_baseline = """import random
import numpy as np
from scheduler_simulator import Scheduler
from operators import *

class GeneticAlgorithm:
    def __init__(self, instance, pop_size=40, generations=60):
        self.inst = instance
        self.scheduler = Scheduler(instance)
        self.pop_size = pop_size
        self.generations = generations

        self.mutations = [swap_mutation, pairwise_swap, inversion_mutation]
        self.crossovers = [one_point_crossover, two_point_crossover, uniform_crossover]

    # ------------------------------------------
    def create_chromosome(self):
        chrom = []
        for t in range(self.inst.n_tasks):
            chrom += [t] * self.inst.subtasks_per_task[t]
        random.shuffle(chrom)
        return chrom

    # ------------------------------------------
    def init_population(self):
        return [self.create_chromosome() for _ in range(self.pop_size)]

    # ------------------------------------------
    def evaluate_population(self, pop):
        return [self.scheduler.evaluate(ind) for ind in pop]

    # ------------------------------------------
    def tournament_selection(self, pop, fitness, k=3):
        selected = random.sample(range(len(pop)), k)
        best = min(selected, key=lambda i: fitness[i])
        return pop[best]

    # ------------------------------------------
    def run(self):
        population = self.init_population()
        best_global = None
        best_fit = 1e18

        for gen in range(self.generations):
            fitness = self.evaluate_population(population)

            # elitism
            elite_idx = np.argmin(fitness)
            elite = population[elite_idx]

            if fitness[elite_idx] < best_fit:
                best_fit = fitness[elite_idx]
                best_global = elite

            new_pop = [elite]

            while len(new_pop) < self.pop_size:
                p1 = self.tournament_selection(population, fitness)
                p2 = self.tournament_selection(population, fitness)

                crossover = random.choice(self.crossovers)
                c1, c2 = crossover(p1.copy(), p2.copy())

                mutation = random.choice(self.mutations)
                c1 = mutation(c1)
                c2 = mutation(c2)

                new_pop += [c1, c2]

            population = new_pop[:self.pop_size]
            print(f"Gen {gen}  Best = {best_fit}")

        return best_global, best_fit
"""
with open('ga_baseline.py', 'w') as f:
    f.write(module_content_ga_baseline)


from instance_generator import generate_instance
from ga_baseline import GeneticAlgorithm

inst = generate_instance("small")

ga = GeneticAlgorithm(inst)
best_sol, best_fit = ga.run()

print("Final Makespan:", best_fit)
# Out:
# Gen 0  Best = 393
# Gen 1  Best = 347
# Gen 2  Best = 323
# Gen 3  Best = 323
# Gen 4  Best = 309
# Gen 5  Best = 291
# Gen 6  Best = 291
# Gen 7  Best = 266
# Gen 8  Best = 266
# Gen 9  Best = 266
# Gen 10  Best = 265
# Gen 11  Best = 263
# Gen 12  Best = 248
# Gen 13  Best = 243
# Gen 14  Best = 243
# Gen 15  Best = 234
# Gen 16  Best = 234
# Gen 17  Best = 234
# Gen 18  Best = 232
# Gen 19  Best = 222
# Gen 20  Best = 222
# Gen 21  Best = 222
# Gen 22  Best = 222
# Gen 23  Best = 222
# Gen 24  Best = 222
# Gen 25  Best = 222
# Gen 26  Best = 222
# Gen 27  Best = 222
# Gen 28  Best = 222
# Gen 29  Best = 222
# Gen 30  Best = 222
# Gen 31  Best = 222
# Gen 32  Best = 222
# Gen 33  Best = 222
# Gen 34  Best = 222
# Gen 35  Best = 222
# Gen 36  Best = 222
# Gen 37  Best = 222
# Gen 38  Best = 222
# Gen 39  Best = 222
# Gen 40  Best = 222
# Gen 41  Best = 222
# Gen 42  Best = 222
# Gen 43  Best = 222
# Gen 44  Best = 222
# Gen 45  Best = 222
# Gen 46  Best = 222
# Gen 47  Best = 222
# Gen 48  Best = 222
# Gen 49  Best = 222
# Gen 50  Best = 222
# Gen 51  Best = 222
# Gen 52  Best = 222
# Gen 53  Best = 222
# Gen 54  Best = 222
# Gen 55  Best = 222
# Gen 56  Best = 222
# Gen 57  Best = 222
# Gen 58  Best = 222
# Gen 59  Best = 222
# Final Makespan: 222

# %% [markdown]
# ##🤖 Step 4 — Q-Learning module (مغز QLGA)

# %%
prev_best = makespan
current_best = best_fit
improvement = prev_best - current_best

print(f"Initial makespan (random chromosome): {prev_best}")
print(f"GA-optimized makespan: {current_best}")
print(f"Improvement: {improvement}")
# Out:
# Initial makespan (random chromosome): 300
# GA-optimized makespan: 222
# Improvement: 78

# %%
if improvement > 20:
    state = 0
elif 0 < improvement <= 20:
    state = 1
else:
    state = 2

print(f"Improvement: {improvement}, State: {state}")
# Out:
# Improvement: 78, State: 0

# %% [markdown]
# ##Actions

# %% [markdown]
# 0 swap mutation
# 1 pairwise swap
# 2 inversion
# 3 one-point crossover
# 4 two-point crossover
# 5 uniform crossover

# %% [markdown]
# ##📦 q_learning.p

# %%
import numpy as np
import random

class QLearningAgent:
    def __init__(self, n_states=3, n_actions=6,
                 alpha=0.1, gamma=0.9, epsilon=0.2):

        self.Q = np.zeros((n_states, n_actions))
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    # ---------------------------------
    def get_state(self, improvement):
        if improvement > 20:
            return 0
        elif improvement > 0:
            return 1
        else:
            return 2

    # ---------------------------------
    def choose_action(self, state):
        # ε-greedy
        if random.random() < self.epsilon:
            return random.randint(0,5)
        return np.argmax(self.Q[state])

    # ---------------------------------
    def update(self, state, action, reward, next_state):
        best_next = np.max(self.Q[next_state])

        self.Q[state, action] += self.alpha * (
            reward + self.gamma * best_next - self.Q[state, action]
        )

# %% [markdown]
# ##🏆 Step 5 — پیاده‌سازی QLGA (الگوریتم پیشنهادی مقاله)

# %% [markdown]
# ##📦 File qlga.py

# %%
import random
import numpy as np

# Create q_learning.py
module_content_q_learning = """import numpy as np
import random

class QLearningAgent:
    def __init__(self, n_states=3, n_actions=6,
                 alpha=0.1, gamma=0.9, epsilon=0.2):

        self.Q = np.zeros((n_states, n_actions))
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    # ---------------------------------
    def get_state(self, improvement):
        if improvement > 20:
            return 0
        elif improvement > 0:
            return 1
        else:
            return 2

    # ---------------------------------
    def choose_action(self, state):
        # \u03b5-greedy
        if random.random() < self.epsilon:
            return random.randint(0,5)
        return np.argmax(self.Q[state])

    # ---------------------------------
    def update(self, state, action, reward, next_state):
        best_next = np.max(self.Q[next_state])

        self.Q[state, action] += self.alpha * (
            reward + self.gamma * best_next - self.Q[state, action]
        )"""

with open('q_learning.py', 'w') as f:
    f.write(module_content_q_learning)


from scheduler_simulator import Scheduler
from operators import *
from q_learning import QLearningAgent

class QLGA:
    def __init__(self, instance, pop_size=40, generations=60):
        self.inst = instance
        self.scheduler = Scheduler(instance)
        self.pop_size = pop_size
        self.generations = generations

        self.rl = QLearningAgent()

        # mapping action -> operator
        self.mutations = [swap_mutation, pairwise_swap, inversion_mutation]
        self.crossovers = [one_point_crossover, two_point_crossover, uniform_crossover]

    # -------------------------------------------------
    def create_chromosome(self):
        chrom = []
        for t in range(self.inst.n_tasks):
            chrom += [t] * self.inst.subtasks_per_task[t]
        random.shuffle(chrom)
        return chrom

    def init_population(self):
        return [self.create_chromosome() for _ in range(self.pop_size)]

    def evaluate_population(self, pop):
        return [self.scheduler.evaluate(ind) for ind in pop]

    def tournament_selection(self, pop, fitness, k=3):
        selected = random.sample(range(len(pop)), k)
        best = min(selected, key=lambda i: fitness[i])
        return pop[best]

    # -------------------------------------------------
    def apply_action(self, action, p1, p2):
        # mutation actions
        if action <= 2:
            op = self.mutations[action]
            return op(p1.copy()), op(p2.copy())
        # crossover actions
        else:
            op = self.crossovers[action-3]
            return op(p1.copy(), p2.copy())

    # -------------------------------------------------
    def run(self):
        population = self.init_population()

        best_global = None
        best_fit = 1e18
        prev_best = 1e18

        state = 2  # start as stagnation

        for gen in range(self.generations):
            fitness = self.evaluate_population(population)
            elite_idx = np.argmin(fitness)
            elite = population[elite_idx]
            current_best = fitness[elite_idx]

            # ---------- RL state ----------
            improvement = prev_best - current_best
            next_state = self.rl.get_state(improvement)

            # ---------- choose operator ----------
            action = self.rl.choose_action(state)

            # ---------- GA reproduction ----------
            new_pop = [elite]

            while len(new_pop) < self.pop_size:
                p1 = self.tournament_selection(population, fitness)
                p2 = self.tournament_selection(population, fitness)

                c1, c2 = self.apply_action(action, p1, p2)
                new_pop += [c1, c2]

            population = new_pop[:self.pop_size]

            # ---------- reward ----------
            reward = prev_best - current_best
            if reward <= 0:
                reward = -5

            # ---------- update Q ----------
            self.rl.update(state, action, reward, next_state)

            state = next_state
            prev_best = current_best

            if current_best < best_fit:
                best_fit = current_best
                best_global = elite

            print(f"Gen {gen} | Best {best_fit} | Action {action}")

        return best_global, best_fit

# %% [markdown]
# ##🧪 تست الگوریتم مقاله

# %%
# module_content for instance_generator.py
module_content_instance = """import numpy as np
import random

class CMgInstance:
    def __init__(self, n_tasks=10, n_providers=3):
        self.n_tasks = n_tasks
        self.n_providers = n_providers

        # ---------- GENERATE STRUCTURE ----------
        self.subtasks_per_task = [random.randint(2,5) for _ in range(n_tasks)]
        self.machines_per_provider = [random.randint(2,5) for _ in range(n_providers)]

        # ---------- ARRIVAL TIMES ----------
        self.arrival_time = np.random.randint(0,200, size=n_tasks)

        # ---------- PROCESSING TIMES ----------
        # P[i][j][k][r]
        self.processing_time = self.generate_processing_times()

        # ---------- LOGISTICS ----------
        self.TSS = np.random.randint(5,30,(n_providers,n_providers))  # SP to SP
        self.TSC = np.random.randint(5,50,(n_providers,n_tasks))      # SP to customer

    # -----------------------------------------
    def generate_processing_times(self):
        P = {}
        for i in range(self.n_tasks):
            P[i] = {}
            for j in range(self.subtasks_per_task[i]):
                P[i][j] = {}
                for k in range(self.n_providers):
                    P[i][j][k] = {}
                    for r in range(self.machines_per_provider[k]):
                        P[i][j][k][r] = random.randint(10,100)
        return P

# ----------- helper to create benchmark sizes ----------
def generate_instance(size="small"):

    if size == "small":
        return CMgInstance(n_tasks=10, n_providers=3)
    elif size == "medium":
        return CMgInstance(n_tasks=20, n_providers=5)
    else:
        return CMgInstance(n_tasks=35, n_providers=8)
"""
with open('instance_generator.py', 'w') as f:
    f.write(module_content_instance)


# module_content for scheduler_simulator.py
module_content_scheduler = """import numpy as np
from collections import defaultdict

class Scheduler:
    def __init__(self, instance):
        self.inst = instance

    # --------------------------------------------------
    # انتخاب بهترین ماشین برای یک عملیات
    # --------------------------------------------------
    def select_best_machine(self, task, subtask, ready_time):
        best_finish = 1e18
        best_choice = None

        for k in range(self.inst.n_providers):
            for r in range(self.inst.machines_per_provider[k]):

                proc_time = self.inst.processing_time[task][subtask][k][r]
                finish_time = ready_time + proc_time

                if finish_time < best_finish:
                    best_finish = finish_time
                    best_choice = (k,r,proc_time)

        return best_choice  # provider, machine, processing_time

    # --------------------------------------------------
    # DECODE chromosome → schedule → makespan
    # --------------------------------------------------
    def evaluate(self, chromosome):

        # زمان آزاد شدن ماشین‌ها
        machine_available = defaultdict(int)

        # پایان آخرین subtask هر task
        task_last_finish = defaultdict(int)

        # شماره subtask بعدی که باید اجرا شود
        next_subtask_index = defaultdict(int)

        # شروع کار = arrival time
        for t in range(self.inst.n_tasks):
            task_last_finish[t] = self.inst.arrival_time[t]

        # ----------------------------------------------
        for gene in chromosome:
            task = gene

            subtask = next_subtask_index[task]

            # اگر همه subtasks انجام شده → رد کن
            if subtask >= self.inst.subtasks_per_task[task]:
                continue

            ready_time = task_last_finish[task]

            # انتخاب بهترین ماشین
            provider, machine, proc_time = self.select_best_machine(
                task, subtask, ready_time
            )

            machine_key = (provider, machine)
            start_time = max(machine_available[machine_key], ready_time)
            finish_time = start_time + proc_time

            # آپدیت وضعیت‌ها
            machine_available[machine_key] = finish_time
            task_last_finish[task] = finish_time
            next_subtask_index[task] += 1

        # ----------------------------------------------
        # makespan = آخرین پایان
        makespan = max(task_last_finish.values())
        return makespan
"""
with open('scheduler_simulator.py', 'w') as f:
    f.write(module_content_scheduler)


# module_content for operators.py
module_content_operators = """import random

# -----------------------------
# MUTATIONS
# -----------------------------
def swap_mutation(chrom):
    a, b = random.sample(range(len(chrom)), 2)
    chrom[a], chrom[b] = chrom[b], chrom[a]
    return chrom

def pairwise_swap(chrom):
    for i in range(0, len(chrom)-1, 2):
        if random.random() < 0.5:
            chrom[i], chrom[i+1] = chrom[i+1], chrom[i]
    return chrom

def inversion_mutation(chrom):
    a, b = sorted(random.sample(range(len(chrom)), 2))
    chrom[a:b] = reversed(chrom[a:b])
    return chrom

# -----------------------------
# CROSSOVERS
# -----------------------------
def one_point_crossover(p1, p2):
    cut = random.randint(1, len(p1)-2)
    c1 = p1[:cut] + p2[cut:]
    c2 = p2[:cut] + p1[cut:]
    return c1, c2

def two_point_crossover(p1, p2):
    a, b = sorted(random.sample(range(len(p1)), 2))
    c1 = p1[:a] + p2[a:b] + p1[b:]
    c2 = p2[:a] + p1[a:b] + p2[b:]
    return c1, c2

def uniform_crossover(p1, p2):
    c1, c2 = [], []
    for g1, g2 in zip(p1, p2):
        if random.random() < 0.5:
            c1.append(g1); c2.append(g2)
        else:
            c1.append(g2); c2.append(g1)
    return c1, c2
"""
with open('operators.py', 'w') as f:
    f.write(module_content_operators)


# module_content for q_learning.py
module_content_q_learning = """import numpy as np
import random

class QLearningAgent:
    def __init__(self, n_states=3, n_actions=6,
                 alpha=0.1, gamma=0.9, epsilon=0.2):

        self.Q = np.zeros((n_states, n_actions))
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    # ---------------------------------
    def get_state(self, improvement):
        if improvement > 20:
            return 0
        elif improvement > 0:
            return 1
        else:
            return 2

    # ---------------------------------
    def choose_action(self, state):
        # \u03b5-greedy
        if random.random() < self.epsilon:
            return random.randint(0,5)
        return np.argmax(self.Q[state])

    # ---------------------------------
    def update(self, state, action, reward, next_state):
        best_next = np.max(self.Q[next_state])

        self.Q[state, action] += self.alpha * (
            reward + self.gamma * best_next - self.Q[state, action]
        )"""

with open('q_learning.py', 'w') as f:
    f.write(module_content_q_learning)


# module_content for qlga.py
module_content_qlga = """import random
import numpy as np

from scheduler_simulator import Scheduler
from operators import *
from q_learning import QLearningAgent

class QLGA:
    def __init__(self, instance, pop_size=40, generations=60):
        self.inst = instance
        self.scheduler = Scheduler(instance)
        self.pop_size = pop_size
        self.generations = generations

        self.rl = QLearningAgent()

        # mapping action -> operator
        self.mutations = [swap_mutation, pairwise_swap, inversion_mutation]
        self.crossovers = [one_point_crossover, two_point_crossover, uniform_crossover]

    # -------------------------------------------------
    def create_chromosome(self):
        chrom = []
        for t in range(self.inst.n_tasks):
            chrom += [t] * self.inst.subtasks_per_task[t]
        random.shuffle(chrom)
        return chrom

    def init_population(self):
        return [self.create_chromosome() for _ in range(self.pop_size)]

    def evaluate_population(self, pop):
        return [self.scheduler.evaluate(ind) for ind in pop]

    def tournament_selection(self, pop, fitness, k=3):
        selected = random.sample(range(len(pop)), k)
        best = min(selected, key=lambda i: fitness[i])
        return pop[best]

    # -------------------------------------------------
    def apply_action(self, action, p1, p2):
        # mutation actions
        if action <= 2:
            op = self.mutations[action]
            return op(p1.copy()), op(p2.copy())
        # crossover actions
        else:
            op = self.crossovers[action-3]
            return op(p1.copy(), p2.copy())

    # -------------------------------------------------
    def run(self):
        population = self.init_population()

        best_global = None
        best_fit = 1e18
        prev_best = 1e18

        state = 2  # start as stagnation

        for gen in range(self.generations):
            fitness = self.evaluate_population(population)
            elite_idx = np.argmin(fitness)
            elite = population[elite_idx]
            current_best = fitness[elite_idx]

            # ---------- RL state ----------
            improvement = prev_best - current_best
            next_state = self.rl.get_state(improvement)

            # ---------- choose operator ----------
            action = self.rl.choose_action(state)

            # ---------- GA reproduction ----------
            new_pop = [elite]

            while len(new_pop) < self.pop_size:
                p1 = self.tournament_selection(population, fitness)
                p2 = self.tournament_selection(population, fitness)

                c1, c2 = self.apply_action(action, p1, p2)
                new_pop += [c1, c2]

            population = new_pop[:self.pop_size]

            # ---------- reward ----------
            reward = prev_best - current_best
            if reward <= 0:
                reward = -5

            # ---------- update Q ----------
            self.rl.update(state, action, reward, next_state)

            state = next_state
            prev_best = current_best

            if current_best < best_fit:
                best_fit = current_best
                best_global = elite

            print(f"Gen {gen} | Best {best_fit} | Action {action}")

        return best_global, best_fit
"""
with open('qlga.py', 'w') as f:
    f.write(module_content_qlga)


from instance_generator import generate_instance
from qlga import QLGA

inst = generate_instance("small")

qlga = QLGA(inst)
best_sol, best_fit = qlga.run()

print("\nFinal Makespan QLGA:", best_fit)
# Out:
# Gen 0 | Best 305 | Action 0
# Gen 1 | Best 300 | Action 0
# Gen 2 | Best 300 | Action 0
# Gen 3 | Best 300 | Action 0
# Gen 4 | Best 300 | Action 0
# Gen 5 | Best 300 | Action 0
# Gen 6 | Best 300 | Action 0
# Gen 7 | Best 300 | Action 0
# Gen 8 | Best 300 | Action 0
# Gen 9 | Best 300 | Action 5
# Gen 10 | Best 255 | Action 0
# Gen 11 | Best 255 | Action 0
# Gen 12 | Best 255 | Action 0
# Gen 13 | Best 255 | Action 0
# Gen 14 | Best 255 | Action 0
# Gen 15 | Best 255 | Action 2
# Gen 16 | Best 255 | Action 0
# Gen 17 | Best 255 | Action 5
# Gen 18 | Best 246 | Action 0
# Gen 19 | Best 246 | Action 0
# Gen 20 | Best 246 | Action 0
# Gen 21 | Best 242 | Action 0
# Gen 22 | Best 236 | Action 2
# Gen 23 | Best 236 | Action 4
# Gen 24 | Best 236 | Action 0
# Gen 25 | Best 236 | Action 1
# Gen 26 | Best 236 | Action 2
# Gen 27 | Best 235 | Action 3
# Gen 28 | Best 230 | Action 0
# Gen 29 | Best 230 | Action 0
# Gen 30 | Best 230 | Action 0
# Gen 31 | Best 230 | Action 0
# Gen 32 | Best 230 | Action 0
# Gen 33 | Best 228 | Action 0
# Gen 34 | Best 228 | Action 0
# Gen 35 | Best 228 | Action 0
# Gen 36 | Best 228 | Action 0
# Gen 37 | Best 228 | Action 0
# Gen 38 | Best 228 | Action 0
# Gen 39 | Best 228 | Action 0
# Gen 40 | Best 228 | Action 0
# Gen 41 | Best 228 | Action 2
# Gen 42 | Best 228 | Action 0
# Gen 43 | Best 228 | Action 0
# Gen 44 | Best 228 | Action 0
# Gen 45 | Best 228 | Action 0
# Gen 46 | Best 228 | Action 2
# Gen 47 | Best 228 | Action 0
# Gen 48 | Best 228 | Action 4
# Gen 49 | Best 228 | Action 0
# Gen 50 | Best 228 | Action 0
# Gen 51 | Best 228 | Action 0
# Gen 52 | Best 228 | Action 0
# Gen 53 | Best 228 | Action 0
# Gen 54 | Best 228 | Action 1
# Gen 55 | Best 228 | Action 0
# Gen 56 | Best 228 | Action 0
# Gen 57 | Best 228 | Action 0
# Gen 58 | Best 228 | Action 0
# Gen 59 | Best 228 | Action 0
#
# Final Makespan QLGA: 228

# %% [markdown]
# ##📈 Step 6 — اجرای آزمایش‌ها و رسم نمودار (Reproducibility)

# %% [markdown]
# ##📦 File Experiments.py

# %%
import numpy as np
from instance_generator import generate_instance
from ga_baseline import GeneticAlgorithm
from qlga import QLGA
import matplotlib.pyplot as plt

def run_algorithm(algo_class, size, runs=5):
    results = []

    for r in range(runs):
        inst = generate_instance(size)
        algo = algo_class(inst)
        _, best_fit = algo.run()
        results.append(best_fit)

    return np.mean(results), np.std(results)

# --------------------------------------------
sizes = ["small", "medium", "large"]

ga_means = []
qlga_means = []

for s in sizes:
    print("\n===== SIZE:", s, "=====")

    ga_mean, _ = run_algorithm(GeneticAlgorithm, s)
    qlga_mean, _ = run_algorithm(QLGA, s)

    ga_means.append(ga_mean)
    qlga_means.append(qlga_mean)

# --------------------------------------------
# PLOT
plt.figure()
plt.plot(sizes, ga_means, marker='o', label="GA")
plt.plot(sizes, qlga_means, marker='o', label="QLGA")
plt.ylabel("Average Makespan")
plt.title("GA vs QLGA")
plt.legend()
plt.grid()

plt.savefig("result.png")
plt.show()
# Out:
# ===== SIZE: small =====
# Gen 0  Best = 257
# Gen 1  Best = 238
# Gen 2  Best = 221
# Gen 3  Best = 220
# Gen 4  Best = 220
# Gen 5  Best = 214
# Gen 6  Best = 214
# Gen 7  Best = 214
# Gen 8  Best = 209
# Gen 9  Best = 209
# Gen 10  Best = 209
# Gen 11  Best = 209
# Gen 12  Best = 199
# Gen 13  Best = 199
# Gen 14  Best = 199
# Gen 15  Best = 199
# Gen 16  Best = 190
# Gen 17  Best = 186
# Gen 18  Best = 186
# Gen 19  Best = 183
# Gen 20  Best = 183
# Gen 21  Best = 183
# Gen 22  Best = 172
# Gen 23  Best = 172
# Gen 24  Best = 170
# Gen 25  Best = 170
# Gen 26  Best = 170
# Gen 27  Best = 170
# Gen 28  Best = 170
# Gen 29  Best = 170
# Gen 30  Best = 170
# Gen 31  Best = 170
# Gen 32  Best = 170
# Gen 33  Best = 170
# Gen 34  Best = 170
# Gen 35  Best = 170
# Gen 36  Best = 170
# Gen 37  Best = 170
# Gen 38  Best = 170
# Gen 39  Best = 170
# Gen 40  Best = 170
# Gen 41  Best = 170
# Gen 42  Best = 170
# Gen 43  Best = 170
# Gen 44  Best = 170
# Gen 45  Best = 170
# Gen 46  Best = 170
# Gen 47  Best = 170
# Gen 48  Best = 170
# Gen 49  Best = 170
# Gen 50  Best = 170
# Gen 51  Best = 170
# Gen 52  Best = 170
# Gen 53  Best = 170
# Gen 54  Best = 170
# Gen 55  Best = 170
# Gen 56  Best = 170
# Gen 57  Best = 170
# Gen 58  Best = 170
# Gen 59  Best = 170
# Gen 0  Best = 198
# Gen 1  Best = 190
# Gen 2  Best = 172
# Gen 3  Best = 172
# Gen 4  Best = 170
# Gen 5  Best = 170
# Gen 6  Best = 167
# Gen 7  Best = 167
# Gen 8  Best = 150
# Gen 9  Best = 150
# Gen 10  Best = 150
# Gen 11  Best = 148
# Gen 12  Best = 148
# Gen 13  Best = 148
# Gen 14  Best = 148
# Gen 15  Best = 148
# Gen 16  Best = 148
# Gen 17  Best = 148
# Gen 18  Best = 148
# Gen 19  Best = 148
# Gen 20  Best = 148
# Gen 21  Best = 148
# Gen 22  Best = 148
# Gen 23  Best = 148
# Gen 24  Best = 148
# Gen 25  Best = 148
# Gen 26  Best = 148
# Gen 27  Best = 148
# Gen 28  Best = 148
# Gen 29  Best = 148
# Gen 30  Best = 148
# Gen 31  Best = 148
# Gen 32  Best = 148
# Gen 33  Best = 148
# Gen 34  Best = 148
# Gen 35  Best = 148
# Gen 36  Best = 148
# Gen 37  Best = 148
# Gen 38  Best = 148
# Gen 39  Best = 148
# Gen 40  Best = 148
# Gen 41  Best = 148
# Gen 42  Best = 148
# Gen 43  Best = 148
# Gen 44  Best = 148
# Gen 45  Best = 148
# Gen 46  Best = 148
# Gen 47  Best = 148
# Gen 48  Best = 148
# Gen 49  Best = 148
# Gen 50  Best = 148
# Gen 51  Best = 148
# Gen 52  Best = 148
# Gen 53  Best = 148
# Gen 54  Best = 148
# Gen 55  Best = 148
# Gen 56  Best = 148
# Gen 57  Best = 148
# Gen 58  Best = 148
# Gen 59  Best = 148
# Gen 0  Best = 329
# Gen 1  Best = 293
# Gen 2  Best = 276
# Gen 3  Best = 266
# Gen 4  Best = 266
# Gen 5  Best = 263
# Gen 6  Best = 263
# Gen 7  Best = 263
# Gen 8  Best = 258
# Gen 9  Best = 258
# Gen 10  Best = 245
# Gen 11  Best = 245
# Gen 12  Best = 245
# Gen 13  Best = 245
# Gen 14  Best = 245
# Gen 15  Best = 245
# Gen 16  Best = 243
# Gen 17  Best = 243
# Gen 18  Best = 243
# Gen 19  Best = 241
# Gen 20  Best = 241
# Gen 21  Best = 236
# Gen 22  Best = 236
# Gen 23  Best = 236
# Gen 24  Best = 236
# Gen 25  Best = 236
# Gen 26  Best = 229
# Gen 27  Best = 221
# Gen 28  Best = 221
# Gen 29  Best = 221
# Gen 30  Best = 221
# Gen 31  Best = 218
# Gen 32  Best = 203
# Gen 33  Best = 203
# Gen 34  Best = 193
# Gen 35  Best = 193
# Gen 36  Best = 193
# Gen 37  Best = 184
# Gen 38  Best = 184
# Gen 39  Best = 184
# Gen 40  Best = 176
# Gen 41  Best = 169
# Gen 42  Best = 169
# Gen 43  Best = 169
# Gen 44  Best = 169
# Gen 45  Best = 169
# Gen 46  Best = 169
# Gen 47  Best = 169
# Gen 48  Best = 169
# Gen 49  Best = 169
# Gen 50  Best = 169
# Gen 51  Best = 169
# Gen 52  Best = 169
# Gen 53  Best = 169
# Gen 54  Best = 169
# Gen 55  Best = 169
# Gen 56  Best = 169
# Gen 57  Best = 169
# Gen 58  Best = 169
# Gen 59  Best = 169
# Gen 0  Best = 280
# Gen 1  Best = 234
# Gen 2  Best = 227
# Gen 3  Best = 227
# Gen 4  Best = 226
# Gen 5  Best = 226
# Gen 6  Best = 214
# Gen 7  Best = 214
# Gen 8  Best = 206
# Gen 9  Best = 206
# Gen 10  Best = 203
# Gen 11  Best = 203
# Gen 12  Best = 203
# Gen 13  Best = 202
# Gen 14  Best = 200
# Gen 15  Best = 198
# Gen 16  Best = 198
# Gen 17  Best = 188
# Gen 18  Best = 188
# Gen 19  Best = 186
# Gen 20  Best = 186
# Gen 21  Best = 186
# Gen 22  Best = 184
# Gen 23  Best = 184
# Gen 24  Best = 184
# Gen 25  Best = 184
# Gen 26  Best = 184
# Gen 27  Best = 184
# Gen 28  Best = 184
# Gen 29  Best = 184
# Gen 30  Best = 184
# Gen 31  Best = 184
# Gen 32  Best = 184
# Gen 33  Best = 184
# Gen 34  Best = 184
# Gen 35  Best = 184
# Gen 36  Best = 184
# Gen 37  Best = 184
# Gen 38  Best = 184
# Gen 39  Best = 184
# Gen 40  Best = 184
# Gen 41  Best = 172
# Gen 42  Best = 172
# Gen 43  Best = 172
# Gen 44  Best = 172
# Gen 45  Best = 172
# Gen 46  Best = 172
# Gen 47  Best = 172
# Gen 48  Best = 172
# Gen 49  Best = 172
# Gen 50  Best = 172
# Gen 51  Best = 172
# Gen 52  Best = 172
# Gen 53  Best = 172
# Gen 54  Best = 172
# Gen 55  Best = 164
# Gen 56  Best = 164
# Gen 57  Best = 164
# Gen 58  Best = 164
# Gen 59  Best = 164
# Gen 0  Best = 191
# Gen 1  Best = 181
# Gen 2  Best = 178
# Gen 3  Best = 163
# Gen 4  Best = 163
# Gen 5  Best = 163
# Gen 6  Best = 163
# Gen 7  Best = 163
# Gen 8  Best = 162
# Gen 9  Best = 162
# Gen 10  Best = 162
# Gen 11  Best = 162
# Gen 12  Best = 162
# Gen 13  Best = 162
# Gen 14  Best = 162
# Gen 15  Best = 162
# Gen 16  Best = 162
# Gen 17  Best = 162
# Gen 18  Best = 162
# Gen 19  Best = 162
# Gen 20  Best = 162
# Gen 21  Best = 162
# Gen 22  Best = 162
# Gen 23  Best = 153
# Gen 24  Best = 153
# Gen 25  Best = 153
# Gen 26  Best = 153
# Gen 27  Best = 150
# Gen 28  Best = 150
# Gen 29  Best = 150
# Gen 30  Best = 150
# Gen 31  Best = 150
# Gen 32  Best = 150
# Gen 33  Best = 150
# Gen 34  Best = 150
# Gen 35  Best = 150
# Gen 36  Best = 150
# Gen 37  Best = 150
# Gen 38  Best = 142
# Gen 39  Best = 142
# Gen 40  Best = 140
# Gen 41  Best = 140
# Gen 42  Best = 140
# Gen 43  Best = 140
# Gen 44  Best = 140
# Gen 45  Best = 140
# Gen 46  Best = 140
# Gen 47  Best = 140
# Gen 48  Best = 140
# Gen 49  Best = 140
# Gen 50  Best = 140
# Gen 51  Best = 140
# Gen 52  Best = 140
# Gen 53  Best = 140
# Gen 54  Best = 140
# Gen 55  Best = 140
# Gen 56  Best = 140
# Gen 57  Best = 140
# Gen 58  Best = 140
# Gen 59  Best = 140
# Gen 0 | Best 259 | Action 0
# Gen 1 | Best 254 | Action 1
# Gen 2 | Best 254 | Action 0
# Gen 3 | Best 254 | Action 0
# Gen 4 | Best 254 | Action 0
# Gen 5 | Best 254 | Action 0
# Gen 6 | Best 254 | Action 0
# Gen 7 | Best 254 | Action 0
# Gen 8 | Best 254 | Action 0
# Gen 9 | Best 254 | Action 0
# Gen 10 | Best 254 | Action 0
# Gen 11 | Best 254 | Action 0
# Gen 12 | Best 254 | Action 4
# Gen 13 | Best 244 | Action 2
# Gen 14 | Best 244 | Action 0
# Gen 15 | Best 244 | Action 0
# Gen 16 | Best 244 | Action 0
# Gen 17 | Best 244 | Action 0
# Gen 18 | Best 244 | Action 0
# Gen 19 | Best 244 | Action 0
# Gen 20 | Best 244 | Action 0
# Gen 21 | Best 244 | Action 0
# Gen 22 | Best 244 | Action 0
# Gen 23 | Best 244 | Action 0
# Gen 24 | Best 244 | Action 0
# Gen 25 | Best 244 | Action 0
# Gen 26 | Best 244 | Action 0
# Gen 27 | Best 244 | Action 4
# Gen 28 | Best 237 | Action 0
# Gen 29 | Best 237 | Action 0
# Gen 30 | Best 237 | Action 0
# Gen 31 | Best 237 | Action 0
# Gen 32 | Best 237 | Action 0
# Gen 33 | Best 237 | Action 0
# Gen 34 | Best 237 | Action 0
# Gen 35 | Best 237 | Action 5
# Gen 36 | Best 224 | Action 0
# Gen 37 | Best 224 | Action 0
# Gen 38 | Best 224 | Action 0
# Gen 39 | Best 224 | Action 0
# Gen 40 | Best 224 | Action 0
# Gen 41 | Best 224 | Action 0
# Gen 42 | Best 224 | Action 0
# Gen 43 | Best 224 | Action 0
# Gen 44 | Best 224 | Action 4
# Gen 45 | Best 214 | Action 1
# Gen 46 | Best 214 | Action 0
# Gen 47 | Best 214 | Action 0
# Gen 48 | Best 214 | Action 3
# Gen 49 | Best 214 | Action 3
# Gen 50 | Best 214 | Action 2
# Gen 51 | Best 214 | Action 3
# Gen 52 | Best 214 | Action 2
# Gen 53 | Best 214 | Action 0
# Gen 54 | Best 214 | Action 0
# Gen 55 | Best 214 | Action 3
# Gen 56 | Best 214 | Action 2
# Gen 57 | Best 214 | Action 0
# Gen 58 | Best 214 | Action 0
# Gen 59 | Best 214 | Action 0
# Gen 0 | Best 293 | Action 0
# Gen 1 | Best 293 | Action 0
# Gen 2 | Best 293 | Action 0
# Gen 3 | Best 293 | Action 1
# Gen 4 | Best 293 | Action 0
# Gen 5 | Best 293 | Action 0
# Gen 6 | Best 283 | Action 0
# Gen 7 | Best 283 | Action 0
# Gen 8 | Best 283 | Action 0
# Gen 9 | Best 283 | Action 0
# Gen 10 | Best 283 | Action 0
# Gen 11 | Best 283 | Action 0
# Gen 12 | Best 283 | Action 0
# Gen 13 | Best 283 | Action 0
# Gen 14 | Best 283 | Action 0
# Gen 15 | Best 283 | Action 0
# Gen 16 | Best 283 | Action 0
# Gen 17 | Best 283 | Action 0
# Gen 18 | Best 283 | Action 4
# Gen 19 | Best 266 | Action 0
# Gen 20 | Best 260 | Action 0
# Gen 21 | Best 260 | Action 2
# Gen 22 | Best 260 | Action 0
# Gen 23 | Best 260 | Action 0
# Gen 24 | Best 260 | Action 0
# Gen 25 | Best 260 | Action 2
# Gen 26 | Best 260 | Action 0
# Gen 27 | Best 260 | Action 0
# Gen 28 | Best 260 | Action 0
# Gen 29 | Best 260 | Action 0
# Gen 30 | Best 260 | Action 0
# Gen 31 | Best 260 | Action 0
# Gen 32 | Best 260 | Action 0
# Gen 33 | Best 260 | Action 0
# Gen 34 | Best 260 | Action 0
# Gen 35 | Best 260 | Action 0
# Gen 36 | Best 260 | Action 0
# Gen 37 | Best 260 | Action 0
# Gen 38 | Best 260 | Action 0
# Gen 39 | Best 260 | Action 0
# Gen 40 | Best 260 | Action 0
# Gen 41 | Best 260 | Action 0
# Gen 42 | Best 260 | Action 0
# Gen 43 | Best 260 | Action 0
# Gen 44 | Best 260 | Action 0
# Gen 45 | Best 260 | Action 0
# Gen 46 | Best 260 | Action 0
# Gen 47 | Best 260 | Action 0
# Gen 48 | Best 260 | Action 0
# Gen 49 | Best 260 | Action 0
# Gen 50 | Best 260 | Action 3
# Gen 51 | Best 256 | Action 0
# Gen 52 | Best 256 | Action 0
# Gen 53 | Best 256 | Action 0
# Gen 54 | Best 256 | Action 0
# Gen 55 | Best 244 | Action 5
# Gen 56 | Best 244 | Action 0
# Gen 57 | Best 244 | Action 3
# Gen 58 | Best 234 | Action 0
# Gen 59 | Best 234 | Action 0
# Gen 0 | Best 310 | Action 0
# Gen 1 | Best 310 | Action 0
# Gen 2 | Best 310 | Action 0
# Gen 3 | Best 306 | Action 0
# Gen 4 | Best 302 | Action 0
# Gen 5 | Best 302 | Action 0
# Gen 6 | Best 302 | Action 0
# Gen 7 | Best 302 | Action 0
# Gen 8 | Best 302 | Action 0
# Gen 9 | Best 302 | Action 0
# Gen 10 | Best 302 | Action 0
# Gen 11 | Best 302 | Action 5
# Gen 12 | Best 278 | Action 0
# Gen 13 | Best 278 | Action 0
# Gen 14 | Best 278 | Action 0
# Gen 15 | Best 278 | Action 3
# Gen 16 | Best 278 | Action 4
# Gen 17 | Best 278 | Action 0
# Gen 18 | Best 278 | Action 0
# Gen 19 | Best 278 | Action 1
# Gen 20 | Best 278 | Action 0
# Gen 21 | Best 278 | Action 0
# Gen 22 | Best 278 | Action 0
# Gen 23 | Best 278 | Action 0
# Gen 24 | Best 278 | Action 0
# Gen 25 | Best 278 | Action 0
# Gen 26 | Best 278 | Action 0
# Gen 27 | Best 278 | Action 0
# Gen 28 | Best 278 | Action 0
# Gen 29 | Best 278 | Action 4
# Gen 30 | Best 278 | Action 0
# Gen 31 | Best 278 | Action 0
# Gen 32 | Best 278 | Action 0
# Gen 33 | Best 278 | Action 0
# Gen 34 | Best 278 | Action 0
# Gen 35 | Best 278 | Action 0
# Gen 36 | Best 278 | Action 0
# Gen 37 | Best 278 | Action 0
# Gen 38 | Best 278 | Action 0
# Gen 39 | Best 278 | Action 0
# Gen 40 | Best 278 | Action 2
# Gen 41 | Best 278 | Action 0
# Gen 42 | Best 278 | Action 0
# Gen 43 | Best 278 | Action 0
# Gen 44 | Best 278 | Action 0
# Gen 45 | Best 278 | Action 0
# Gen 46 | Best 278 | Action 0
# Gen 47 | Best 278 | Action 5
# Gen 48 | Best 262 | Action 0
# Gen 49 | Best 262 | Action 0
# Gen 50 | Best 262 | Action 0
# Gen 51 | Best 262 | Action 0
# Gen 52 | Best 262 | Action 0
# Gen 53 | Best 262 | Action 0
# Gen 54 | Best 262 | Action 0
# Gen 55 | Best 262 | Action 0
# Gen 56 | Best 262 | Action 0
# Gen 57 | Best 262 | Action 1
# Gen 58 | Best 262 | Action 4
# Gen 59 | Best 262 | Action 0
# Gen 0 | Best 246 | Action 0
# Gen 1 | Best 246 | Action 0
# Gen 2 | Best 246 | Action 0
# Gen 3 | Best 246 | Action 0
# Gen 4 | Best 246 | Action 1
# Gen 5 | Best 246 | Action 0
# Gen 6 | Best 246 | Action 0
# Gen 7 | Best 246 | Action 0
# Gen 8 | Best 246 | Action 2
# Gen 9 | Best 246 | Action 0
# Gen 10 | Best 246 | Action 0
# Gen 11 | Best 246 | Action 0
# Gen 12 | Best 246 | Action 0
# Gen 13 | Best 246 | Action 2
# Gen 14 | Best 246 | Action 0
# Gen 15 | Best 246 | Action 0
# Gen 16 | Best 246 | Action 0
# Gen 17 | Best 246 | Action 0
# Gen 18 | Best 246 | Action 5
# Gen 19 | Best 226 | Action 0
# Gen 20 | Best 226 | Action 0
# Gen 21 | Best 226 | Action 0
# Gen 22 | Best 226 | Action 0
# Gen 23 | Best 225 | Action 0
# Gen 24 | Best 225 | Action 3
# Gen 25 | Best 225 | Action 0
# Gen 26 | Best 225 | Action 0
# Gen 27 | Best 225 | Action 0
# Gen 28 | Best 225 | Action 0
# Gen 29 | Best 225 | Action 0
# Gen 30 | Best 225 | Action 0
# Gen 31 | Best 225 | Action 0
# Gen 32 | Best 225 | Action 0
# Gen 33 | Best 225 | Action 1
# Gen 34 | Best 225 | Action 5
# Gen 35 | Best 209 | Action 0
# Gen 36 | Best 209 | Action 0
# Gen 37 | Best 209 | Action 0
# Gen 38 | Best 209 | Action 1
# Gen 39 | Best 209 | Action 0
# Gen 40 | Best 209 | Action 0
# Gen 41 | Best 209 | Action 0
# Gen 42 | Best 209 | Action 0
# Gen 43 | Best 209 | Action 0
# Gen 44 | Best 209 | Action 0
# Gen 45 | Best 209 | Action 0
# Gen 46 | Best 209 | Action 0
# Gen 47 | Best 209 | Action 0
# Gen 48 | Best 209 | Action 0
# Gen 49 | Best 209 | Action 5
# Gen 50 | Best 201 | Action 0
# Gen 51 | Best 201 | Action 3
# Gen 52 | Best 201 | Action 0
# Gen 53 | Best 201 | Action 0
# Gen 54 | Best 200 | Action 0
# Gen 55 | Best 196 | Action 0
# Gen 56 | Best 196 | Action 0
# Gen 57 | Best 196 | Action 0
# Gen 58 | Best 196 | Action 0
# Gen 59 | Best 196 | Action 0
# Gen 0 | Best 246 | Action 2
# Gen 1 | Best 234 | Action 0
# Gen 2 | Best 234 | Action 0
# Gen 3 | Best 234 | Action 2
# Gen 4 | Best 220 | Action 2
# Gen 5 | Best 220 | Action 0
# Gen 6 | Best 220 | Action 4
# Gen 7 | Best 214 | Action 2
# Gen 8 | Best 214 | Action 5
# Gen 9 | Best 206 | Action 2
# Gen 10 | Best 206 | Action 3
# Gen 11 | Best 206 | Action 2
# Gen 12 | Best 206 | Action 2
# Gen 13 | Best 203 | Action 2
# Gen 14 | Best 203 | Action 0
# Gen 15 | Best 203 | Action 2
# Gen 16 | Best 203 | Action 3
# Gen 17 | Best 202 | Action 2
# Gen 18 | Best 202 | Action 0
# Gen 19 | Best 201 | Action 3
# Gen 20 | Best 201 | Action 0
# Gen 21 | Best 201 | Action 2
# Gen 22 | Best 201 | Action 2
# Gen 23 | Best 201 | Action 2
# Gen 24 | Best 201 | Action 2
# Gen 25 | Best 201 | Action 2
# Gen 26 | Best 201 | Action 2
# Gen 27 | Best 201 | Action 2
# Gen 28 | Best 201 | Action 2
# Gen 29 | Best 201 | Action 2
# Gen 30 | Best 201 | Action 2
# Gen 31 | Best 201 | Action 2
# Gen 32 | Best 201 | Action 3
# Gen 33 | Best 188 | Action 2
# Gen 34 | Best 188 | Action 0
# Gen 35 | Best 188 | Action 2
# Gen 36 | Best 188 | Action 2
# Gen 37 | Best 188 | Action 2
# Gen 38 | Best 188 | Action 2
# Gen 39 | Best 188 | Action 2
# Gen 40 | Best 188 | Action 2
# Gen 41 | Best 188 | Action 2
# Gen 42 | Best 188 | Action 2
# Gen 43 | Best 188 | Action 2
# Gen 44 | Best 188 | Action 2
# Gen 45 | Best 188 | Action 2
# Gen 46 | Best 188 | Action 2
# Gen 47 | Best 188 | Action 2
# Gen 48 | Best 188 | Action 1
# Gen 49 | Best 188 | Action 2
# Gen 50 | Best 188 | Action 2
# Gen 51 | Best 188 | Action 2
# Gen 52 | Best 188 | Action 2
# Gen 53 | Best 188 | Action 2
# Gen 54 | Best 188 | Action 0
# Gen 55 | Best 188 | Action 2
# Gen 56 | Best 188 | Action 2
# Gen 57 | Best 188 | Action 2
# Gen 58 | Best 188 | Action 2
# Gen 59 | Best 188 | Action 2
#
# ===== SIZE: medium =====
# Gen 0  Best = 265
# Gen 1  Best = 230
# Gen 2  Best = 230
# Gen 3  Best = 230
# Gen 4  Best = 229
# Gen 5  Best = 229
# Gen 6  Best = 223
# Gen 7  Best = 211
# Gen 8  Best = 210
# Gen 9  Best = 210
# Gen 10  Best = 210
# Gen 11  Best = 210
# Gen 12  Best = 210
# Gen 13  Best = 209
# Gen 14  Best = 209
# Gen 15  Best = 201
# Gen 16  Best = 199
# Gen 17  Best = 199
# Gen 18  Best = 199
# Gen 19  Best = 199
# Gen 20  Best = 199
# Gen 21  Best = 199
# Gen 22  Best = 199
# Gen 23  Best = 199
# Gen 24  Best = 199
# Gen 25  Best = 199
# Gen 26  Best = 199
# Gen 27  Best = 199
# Gen 28  Best = 199
# Gen 29  Best = 199
# Gen 30  Best = 199
# Gen 31  Best = 199
# Gen 32  Best = 199
# Gen 33  Best = 199
# Gen 34  Best = 199
# Gen 35  Best = 199
# Gen 36  Best = 199
# Gen 37  Best = 199
# Gen 38  Best = 199
# Gen 39  Best = 199
# Gen 40  Best = 199
# Gen 41  Best = 199
# Gen 42  Best = 199
# Gen 43  Best = 199
# Gen 44  Best = 199
# Gen 45  Best = 199
# Gen 46  Best = 199
# Gen 47  Best = 199
# Gen 48  Best = 199
# Gen 49  Best = 199
# Gen 50  Best = 199
# Gen 51  Best = 199
# Gen 52  Best = 199
# Gen 53  Best = 199
# Gen 54  Best = 199
# Gen 55  Best = 199
# Gen 56  Best = 199
# Gen 57  Best = 199
# Gen 58  Best = 199
# Gen 59  Best = 199
# Gen 0  Best = 303
# Gen 1  Best = 278
# Gen 2  Best = 276
# Gen 3  Best = 258
# Gen 4  Best = 258
# Gen 5  Best = 258
# Gen 6  Best = 252
# Gen 7  Best = 251
# Gen 8  Best = 251
# Gen 9  Best = 243
# Gen 10  Best = 243
# Gen 11  Best = 230
# Gen 12  Best = 230
# Gen 13  Best = 230
# Gen 14  Best = 230
# Gen 15  Best = 230
# Gen 16  Best = 230
# Gen 17  Best = 227
# Gen 18  Best = 227
# Gen 19  Best = 227
# Gen 20  Best = 227
# Gen 21  Best = 227
# Gen 22  Best = 227
# Gen 23  Best = 227
# Gen 24  Best = 227
# Gen 25  Best = 227
# Gen 26  Best = 218
# Gen 27  Best = 218
# Gen 28  Best = 218
# Gen 29  Best = 218
# Gen 30  Best = 218
# Gen 31  Best = 214
# Gen 32  Best = 212
# Gen 33  Best = 199
# Gen 34  Best = 199
# Gen 35  Best = 197
# Gen 36  Best = 197
# Gen 37  Best = 197
# Gen 38  Best = 197
# Gen 39  Best = 197
# Gen 40  Best = 197
# Gen 41  Best = 197
# Gen 42  Best = 197
# Gen 43  Best = 197
# Gen 44  Best = 197
# Gen 45  Best = 197
# Gen 46  Best = 197
# Gen 47  Best = 197
# Gen 48  Best = 197
# Gen 49  Best = 197
# Gen 50  Best = 197
# Gen 51  Best = 197
# Gen 52  Best = 197
# Gen 53  Best = 197
# Gen 54  Best = 197
# Gen 55  Best = 197
# Gen 56  Best = 197
# Gen 57  Best = 197
# Gen 58  Best = 197
# Gen 59  Best = 197
# Gen 0  Best = 272
# Gen 1  Best = 272
# Gen 2  Best = 272
# Gen 3  Best = 253
# Gen 4  Best = 244
# Gen 5  Best = 244
# Gen 6  Best = 244
# Gen 7  Best = 244
# Gen 8  Best = 244
# Gen 9  Best = 244
# Gen 10  Best = 244
# Gen 11  Best = 242
# Gen 12  Best = 241
# Gen 13  Best = 224
# Gen 14  Best = 223
# Gen 15  Best = 223
# Gen 16  Best = 223
# Gen 17  Best = 223
# Gen 18  Best = 223
# Gen 19  Best = 223
# Gen 20  Best = 223
# Gen 21  Best = 223
# Gen 22  Best = 223
# Gen 23  Best = 223
# Gen 24  Best = 223
# Gen 25  Best = 223
# Gen 26  Best = 223
# Gen 27  Best = 223
# Gen 28  Best = 223
# Gen 29  Best = 213
# Gen 30  Best = 213
# Gen 31  Best = 211
# Gen 32  Best = 211
# Gen 33  Best = 211
# Gen 34  Best = 211
# Gen 35  Best = 211
# Gen 36  Best = 199
# Gen 37  Best = 199
# Gen 38  Best = 198
# Gen 39  Best = 196
# Gen 40  Best = 196
# Gen 41  Best = 196
# Gen 42  Best = 196
# Gen 43  Best = 196
# Gen 44  Best = 196
# Gen 45  Best = 196
# Gen 46  Best = 196
# Gen 47  Best = 196
# Gen 48  Best = 196
# Gen 49  Best = 196
# Gen 50  Best = 196
# Gen 51  Best = 196
# Gen 52  Best = 196
# Gen 53  Best = 196
# Gen 54  Best = 196
# Gen 55  Best = 196
# Gen 56  Best = 196
# Gen 57  Best = 196
# Gen 58  Best = 196
# Gen 59  Best = 196
# Gen 0  Best = 261
# Gen 1  Best = 249
# Gen 2  Best = 249
# Gen 3  Best = 243
# Gen 4  Best = 236
# Gen 5  Best = 224
# Gen 6  Best = 224
# Gen 7  Best = 205
# Gen 8  Best = 205
# Gen 9  Best = 205
# Gen 10  Best = 205
# Gen 11  Best = 205
# Gen 12  Best = 205
# Gen 13  Best = 198
# Gen 14  Best = 198
# Gen 15  Best = 198
# Gen 16  Best = 198
# Gen 17  Best = 198
# Gen 18  Best = 198
# Gen 19  Best = 198
# Gen 20  Best = 198
# Gen 21  Best = 198
# Gen 22  Best = 198
# Gen 23  Best = 198
# Gen 24  Best = 198
# Gen 25  Best = 198
# Gen 26  Best = 198
# Gen 27  Best = 198
# Gen 28  Best = 198
# Gen 29  Best = 198
# Gen 30  Best = 198
# Gen 31  Best = 198
# Gen 32  Best = 198
# Gen 33  Best = 198
# Gen 34  Best = 198
# Gen 35  Best = 198
# Gen 36  Best = 198
# Gen 37  Best = 198
# Gen 38  Best = 198
# Gen 39  Best = 198
# Gen 40  Best = 198
# Gen 41  Best = 198
# Gen 42  Best = 198
# Gen 43  Best = 198
# Gen 44  Best = 198
# Gen 45  Best = 198
# Gen 46  Best = 198
# Gen 47  Best = 198
# Gen 48  Best = 198
# Gen 49  Best = 198
# Gen 50  Best = 198
# Gen 51  Best = 198
# Gen 52  Best = 198
# Gen 53  Best = 198
# Gen 54  Best = 198
# Gen 55  Best = 198
# Gen 56  Best = 198
# Gen 57  Best = 198
# Gen 58  Best = 198
# Gen 59  Best = 198
# Gen 0  Best = 294
# Gen 1  Best = 274
# Gen 2  Best = 267
# Gen 3  Best = 267
# Gen 4  Best = 264
# Gen 5  Best = 264
# Gen 6  Best = 247
# Gen 7  Best = 236
# Gen 8  Best = 236
# Gen 9  Best = 236
# Gen 10  Best = 236
# Gen 11  Best = 233
# Gen 12  Best = 233
# Gen 13  Best = 233
# Gen 14  Best = 233
# Gen 15  Best = 233
# Gen 16  Best = 225
# Gen 17  Best = 225
# Gen 18  Best = 225
# Gen 19  Best = 225
# Gen 20  Best = 225
# Gen 21  Best = 225
# Gen 22  Best = 225
# Gen 23  Best = 222
# Gen 24  Best = 222
# Gen 25  Best = 222
# Gen 26  Best = 221
# Gen 27  Best = 220
# Gen 28  Best = 220
# Gen 29  Best = 220
# Gen 30  Best = 220
# Gen 31  Best = 217
# Gen 32  Best = 214
# Gen 33  Best = 214
# Gen 34  Best = 214
# Gen 35  Best = 214
# Gen 36  Best = 213
# Gen 37  Best = 213
# Gen 38  Best = 213
# Gen 39  Best = 213
# Gen 40  Best = 213
# Gen 41  Best = 213
# Gen 42  Best = 213
# Gen 43  Best = 213
# Gen 44  Best = 213
# Gen 45  Best = 213
# Gen 46  Best = 213
# Gen 47  Best = 213
# Gen 48  Best = 213
# Gen 49  Best = 213
# Gen 50  Best = 213
# Gen 51  Best = 213
# Gen 52  Best = 213
# Gen 53  Best = 213
# Gen 54  Best = 213
# Gen 55  Best = 213
# Gen 56  Best = 213
# Gen 57  Best = 213
# Gen 58  Best = 213
# Gen 59  Best = 213
# Gen 0 | Best 257 | Action 0
# Gen 1 | Best 257 | Action 0
# Gen 2 | Best 254 | Action 0
# Gen 3 | Best 254 | Action 0
# Gen 4 | Best 254 | Action 0
# Gen 5 | Best 249 | Action 0
# Gen 6 | Best 249 | Action 0
# Gen 7 | Best 246 | Action 2
# Gen 8 | Best 246 | Action 0
# Gen 9 | Best 246 | Action 0
# Gen 10 | Best 246 | Action 0
# Gen 11 | Best 246 | Action 0
# Gen 12 | Best 246 | Action 0
# Gen 13 | Best 246 | Action 0
# Gen 14 | Best 246 | Action 0
# Gen 15 | Best 246 | Action 0
# Gen 16 | Best 246 | Action 0
# Gen 17 | Best 246 | Action 0
# Gen 18 | Best 246 | Action 0
# Gen 19 | Best 246 | Action 0
# Gen 20 | Best 246 | Action 0
# Gen 21 | Best 246 | Action 0
# Gen 22 | Best 246 | Action 0
# Gen 23 | Best 246 | Action 0
# Gen 24 | Best 246 | Action 0
# Gen 25 | Best 246 | Action 0
# Gen 26 | Best 246 | Action 0
# Gen 27 | Best 246 | Action 0
# Gen 28 | Best 246 | Action 0
# Gen 29 | Best 246 | Action 0
# Gen 30 | Best 246 | Action 0
# Gen 31 | Best 246 | Action 0
# Gen 32 | Best 246 | Action 0
# Gen 33 | Best 246 | Action 0
# Gen 34 | Best 246 | Action 0
# Gen 35 | Best 246 | Action 0
# Gen 36 | Best 246 | Action 0
# Gen 37 | Best 246 | Action 0
# Gen 38 | Best 246 | Action 0
# Gen 39 | Best 246 | Action 0
# Gen 40 | Best 246 | Action 4
# Gen 41 | Best 234 | Action 0
# Gen 42 | Best 234 | Action 0
# Gen 43 | Best 234 | Action 0
# Gen 44 | Best 234 | Action 0
# Gen 45 | Best 234 | Action 0
# Gen 46 | Best 234 | Action 0
# Gen 47 | Best 234 | Action 0
# Gen 48 | Best 234 | Action 0
# Gen 49 | Best 234 | Action 0
# Gen 50 | Best 234 | Action 0
# Gen 51 | Best 234 | Action 0
# Gen 52 | Best 234 | Action 0
# Gen 53 | Best 234 | Action 1
# Gen 54 | Best 234 | Action 0
# Gen 55 | Best 234 | Action 0
# Gen 56 | Best 234 | Action 0
# Gen 57 | Best 234 | Action 0
# Gen 58 | Best 234 | Action 0
# Gen 59 | Best 234 | Action 0
# Gen 0 | Best 283 | Action 0
# Gen 1 | Best 283 | Action 2
# Gen 2 | Best 283 | Action 0
# Gen 3 | Best 283 | Action 0
# Gen 4 | Best 264 | Action 0
# Gen 5 | Best 264 | Action 0
# Gen 6 | Best 260 | Action 0
# Gen 7 | Best 253 | Action 5
# Gen 8 | Best 250 | Action 0
# Gen 9 | Best 250 | Action 0
# Gen 10 | Best 250 | Action 4
# Gen 11 | Best 248 | Action 0
# Gen 12 | Best 248 | Action 0
# Gen 13 | Best 248 | Action 0
# Gen 14 | Best 248 | Action 4
# Gen 15 | Best 247 | Action 0
# Gen 16 | Best 247 | Action 0
# Gen 17 | Best 247 | Action 0
# Gen 18 | Best 247 | Action 0
# Gen 19 | Best 247 | Action 0
# Gen 20 | Best 244 | Action 0
# Gen 21 | Best 242 | Action 0
# Gen 22 | Best 242 | Action 5
# Gen 23 | Best 240 | Action 0
# Gen 24 | Best 237 | Action 0
# Gen 25 | Best 237 | Action 0
# Gen 26 | Best 237 | Action 0
# Gen 27 | Best 237 | Action 0
# Gen 28 | Best 237 | Action 0
# Gen 29 | Best 237 | Action 0
# Gen 30 | Best 237 | Action 0
# Gen 31 | Best 237 | Action 0
# Gen 32 | Best 237 | Action 0
# Gen 33 | Best 237 | Action 0
# Gen 34 | Best 237 | Action 3
# Gen 35 | Best 237 | Action 0
# Gen 36 | Best 237 | Action 0
# Gen 37 | Best 237 | Action 0
# Gen 38 | Best 237 | Action 0
# Gen 39 | Best 237 | Action 0
# Gen 40 | Best 234 | Action 4
# Gen 41 | Best 234 | Action 0
# Gen 42 | Best 234 | Action 0
# Gen 43 | Best 233 | Action 0
# Gen 44 | Best 233 | Action 0
# Gen 45 | Best 233 | Action 0
# Gen 46 | Best 233 | Action 0
# Gen 47 | Best 233 | Action 0
# Gen 48 | Best 233 | Action 0
# Gen 49 | Best 233 | Action 1
# Gen 50 | Best 233 | Action 0
# Gen 51 | Best 231 | Action 0
# Gen 52 | Best 231 | Action 0
# Gen 53 | Best 231 | Action 0
# Gen 54 | Best 231 | Action 0
# Gen 55 | Best 231 | Action 0
# Gen 56 | Best 231 | Action 0
# Gen 57 | Best 231 | Action 0
# Gen 58 | Best 231 | Action 0
# Gen 59 | Best 231 | Action 0
# Gen 0 | Best 285 | Action 0
# Gen 1 | Best 281 | Action 0
# Gen 2 | Best 281 | Action 0
# Gen 3 | Best 281 | Action 0
# Gen 4 | Best 279 | Action 0
# Gen 5 | Best 279 | Action 0
# Gen 6 | Best 279 | Action 0
# Gen 7 | Best 279 | Action 0
# Gen 8 | Best 279 | Action 0
# Gen 9 | Best 279 | Action 0
# Gen 10 | Best 279 | Action 0
# Gen 11 | Best 279 | Action 0
# Gen 12 | Best 279 | Action 0
# Gen 13 | Best 279 | Action 1
# Gen 14 | Best 279 | Action 0
# Gen 15 | Best 279 | Action 0
# Gen 16 | Best 279 | Action 0
# Gen 17 | Best 279 | Action 0
# Gen 18 | Best 279 | Action 0
# Gen 19 | Best 279 | Action 0
# Gen 20 | Best 279 | Action 0
# Gen 21 | Best 279 | Action 0
# Gen 22 | Best 279 | Action 2
# Gen 23 | Best 279 | Action 4
# Gen 24 | Best 258 | Action 0
# Gen 25 | Best 257 | Action 0
# Gen 26 | Best 257 | Action 1
# Gen 27 | Best 257 | Action 0
# Gen 28 | Best 257 | Action 0
# Gen 29 | Best 257 | Action 0
# Gen 30 | Best 257 | Action 5
# Gen 31 | Best 246 | Action 0
# Gen 32 | Best 246 | Action 0
# Gen 33 | Best 246 | Action 0
# Gen 34 | Best 246 | Action 0
# Gen 35 | Best 246 | Action 0
# Gen 36 | Best 246 | Action 0
# Gen 37 | Best 246 | Action 0
# Gen 38 | Best 246 | Action 0
# Gen 39 | Best 246 | Action 2
# Gen 40 | Best 246 | Action 0
# Gen 41 | Best 246 | Action 0
# Gen 42 | Best 246 | Action 0
# Gen 43 | Best 246 | Action 0
# Gen 44 | Best 246 | Action 0
# Gen 45 | Best 246 | Action 0
# Gen 46 | Best 246 | Action 0
# Gen 47 | Best 246 | Action 0
# Gen 48 | Best 246 | Action 0
# Gen 49 | Best 246 | Action 0
# Gen 50 | Best 246 | Action 4
# Gen 51 | Best 237 | Action 0
# Gen 52 | Best 237 | Action 0
# Gen 53 | Best 237 | Action 0
# Gen 54 | Best 237 | Action 0
# Gen 55 | Best 237 | Action 3
# Gen 56 | Best 237 | Action 0
# Gen 57 | Best 237 | Action 1
# Gen 58 | Best 237 | Action 2
# Gen 59 | Best 237 | Action 0
# Gen 0 | Best 289 | Action 0
# Gen 1 | Best 271 | Action 0
# Gen 2 | Best 271 | Action 0
# Gen 3 | Best 271 | Action 0
# Gen 4 | Best 271 | Action 0
# Gen 5 | Best 271 | Action 0
# Gen 6 | Best 269 | Action 0
# Gen 7 | Best 269 | Action 0
# Gen 8 | Best 269 | Action 0
# Gen 9 | Best 269 | Action 5
# Gen 10 | Best 258 | Action 0
# Gen 11 | Best 258 | Action 0
# Gen 12 | Best 255 | Action 0
# Gen 13 | Best 255 | Action 0
# Gen 14 | Best 255 | Action 0
# Gen 15 | Best 255 | Action 0
# Gen 16 | Best 255 | Action 0
# Gen 17 | Best 253 | Action 4
# Gen 18 | Best 249 | Action 0
# Gen 19 | Best 249 | Action 4
# Gen 20 | Best 249 | Action 0
# Gen 21 | Best 249 | Action 0
# Gen 22 | Best 249 | Action 0
# Gen 23 | Best 249 | Action 0
# Gen 24 | Best 249 | Action 0
# Gen 25 | Best 249 | Action 0
# Gen 26 | Best 249 | Action 3
# Gen 27 | Best 249 | Action 0
# Gen 28 | Best 249 | Action 0
# Gen 29 | Best 249 | Action 0
# Gen 30 | Best 249 | Action 0
# Gen 31 | Best 249 | Action 0
# Gen 32 | Best 249 | Action 3
# Gen 33 | Best 249 | Action 0
# Gen 34 | Best 249 | Action 0
# Gen 35 | Best 249 | Action 0
# Gen 36 | Best 249 | Action 0
# Gen 37 | Best 249 | Action 0
# Gen 38 | Best 249 | Action 0
# Gen 39 | Best 249 | Action 0
# Gen 40 | Best 249 | Action 0
# Gen 41 | Best 249 | Action 1
# Gen 42 | Best 249 | Action 0
# Gen 43 | Best 249 | Action 0
# Gen 44 | Best 249 | Action 0
# Gen 45 | Best 249 | Action 0
# Gen 46 | Best 249 | Action 5
# Gen 47 | Best 249 | Action 4
# Gen 48 | Best 249 | Action 0
# Gen 49 | Best 249 | Action 0
# Gen 50 | Best 249 | Action 0
# Gen 51 | Best 249 | Action 0
# Gen 52 | Best 249 | Action 4
# Gen 53 | Best 245 | Action 0
# Gen 54 | Best 245 | Action 0
# Gen 55 | Best 245 | Action 0
# Gen 56 | Best 245 | Action 0
# Gen 57 | Best 245 | Action 5
# Gen 58 | Best 245 | Action 0
# Gen 59 | Best 245 | Action 0
# Gen 0 | Best 273 | Action 0
# Gen 1 | Best 273 | Action 5
# Gen 2 | Best 267 | Action 1
# Gen 3 | Best 267 | Action 0
# Gen 4 | Best 267 | Action 3
# Gen 5 | Best 247 | Action 5
# Gen 6 | Best 235 | Action 0
# Gen 7 | Best 235 | Action 0
# Gen 8 | Best 225 | Action 0
# Gen 9 | Best 225 | Action 0
# Gen 10 | Best 225 | Action 0
# Gen 11 | Best 225 | Action 0
# Gen 12 | Best 223 | Action 0
# Gen 13 | Best 223 | Action 0
# Gen 14 | Best 223 | Action 0
# Gen 15 | Best 214 | Action 0
# Gen 16 | Best 214 | Action 0
# Gen 17 | Best 214 | Action 0
# Gen 18 | Best 214 | Action 0
# Gen 19 | Best 214 | Action 0
# Gen 20 | Best 214 | Action 0
# Gen 21 | Best 214 | Action 0
# Gen 22 | Best 213 | Action 2
# Gen 23 | Best 213 | Action 3
# Gen 24 | Best 212 | Action 0
# Gen 25 | Best 212 | Action 1
# Gen 26 | Best 212 | Action 0
# Gen 27 | Best 212 | Action 0
# Gen 28 | Best 212 | Action 0
# Gen 29 | Best 210 | Action 0
# Gen 30 | Best 210 | Action 0
# Gen 31 | Best 210 | Action 0
# Gen 32 | Best 210 | Action 0
# Gen 33 | Best 210 | Action 0
# Gen 34 | Best 210 | Action 0
# Gen 35 | Best 210 | Action 4
# Gen 36 | Best 210 | Action 0
# Gen 37 | Best 210 | Action 0
# Gen 38 | Best 210 | Action 0
# Gen 39 | Best 210 | Action 0
# Gen 40 | Best 210 | Action 0
# Gen 41 | Best 210 | Action 0
# Gen 42 | Best 210 | Action 0
# Gen 43 | Best 210 | Action 0
# Gen 44 | Best 210 | Action 0
# Gen 45 | Best 210 | Action 0
# Gen 46 | Best 210 | Action 0
# Gen 47 | Best 210 | Action 0
# Gen 48 | Best 210 | Action 0
# Gen 49 | Best 210 | Action 0
# Gen 50 | Best 210 | Action 0
# Gen 51 | Best 210 | Action 0
# Gen 52 | Best 210 | Action 0
# Gen 53 | Best 210 | Action 0
# Gen 54 | Best 210 | Action 0
# Gen 55 | Best 210 | Action 0
# Gen 56 | Best 210 | Action 0
# Gen 57 | Best 210 | Action 0
# Gen 58 | Best 210 | Action 0
# Gen 59 | Best 210 | Action 0
#
# ===== SIZE: large =====
# Gen 0  Best = 279
# Gen 1  Best = 279
# Gen 2  Best = 262
# Gen 3  Best = 259
# Gen 4  Best = 259
# Gen 5  Best = 255
# Gen 6  Best = 255
# Gen 7  Best = 255
# Gen 8  Best = 252
# Gen 9  Best = 248
# Gen 10  Best = 248
# Gen 11  Best = 248
# Gen 12  Best = 248
# Gen 13  Best = 245
# Gen 14  Best = 238
# Gen 15  Best = 238
# Gen 16  Best = 238
# Gen 17  Best = 238
# Gen 18  Best = 238
# Gen 19  Best = 238
# Gen 20  Best = 237
# Gen 21  Best = 237
# Gen 22  Best = 233
# Gen 23  Best = 233
# Gen 24  Best = 233
# Gen 25  Best = 230
# Gen 26  Best = 230
# Gen 27  Best = 230
# Gen 28  Best = 230
# Gen 29  Best = 227
# Gen 30  Best = 227
# Gen 31  Best = 227
# Gen 32  Best = 226
# Gen 33  Best = 226
# Gen 34  Best = 223
# Gen 35  Best = 223
# Gen 36  Best = 223
# Gen 37  Best = 223
# Gen 38  Best = 223
# Gen 39  Best = 223
# Gen 40  Best = 222
# Gen 41  Best = 219
# Gen 42  Best = 219
# Gen 43  Best = 219
# Gen 44  Best = 219
# Gen 45  Best = 219
# Gen 46  Best = 213
# Gen 47  Best = 213
# Gen 48  Best = 213
# Gen 49  Best = 213
# Gen 50  Best = 213
# Gen 51  Best = 213
# Gen 52  Best = 213
# Gen 53  Best = 213
# Gen 54  Best = 213
# Gen 55  Best = 213
# Gen 56  Best = 213
# Gen 57  Best = 213
# Gen 58  Best = 213
# Gen 59  Best = 213
# Gen 0  Best = 287
# Gen 1  Best = 271
# Gen 2  Best = 265
# Gen 3  Best = 265
# Gen 4  Best = 265
# Gen 5  Best = 265
# Gen 6  Best = 263
# Gen 7  Best = 263
# Gen 8  Best = 254
# Gen 9  Best = 250
# Gen 10  Best = 242
# Gen 11  Best = 242
# Gen 12  Best = 241
# Gen 13  Best = 238
# Gen 14  Best = 234
# Gen 15  Best = 234
# Gen 16  Best = 234
# Gen 17  Best = 234
# Gen 18  Best = 234
# Gen 19  Best = 234
# Gen 20  Best = 227
# Gen 21  Best = 226
# Gen 22  Best = 226
# Gen 23  Best = 226
# Gen 24  Best = 226
# Gen 25  Best = 226
# Gen 26  Best = 226
# Gen 27  Best = 226
# Gen 28  Best = 226
# Gen 29  Best = 226
# Gen 30  Best = 226
# Gen 31  Best = 226
# Gen 32  Best = 226
# Gen 33  Best = 226
# Gen 34  Best = 226
# Gen 35  Best = 226
# Gen 36  Best = 226
# Gen 37  Best = 226
# Gen 38  Best = 226
# Gen 39  Best = 226
# Gen 40  Best = 226
# Gen 41  Best = 226
# Gen 42  Best = 226
# Gen 43  Best = 226
# Gen 44  Best = 226
# Gen 45  Best = 226
# Gen 46  Best = 226
# Gen 47  Best = 226
# Gen 48  Best = 226
# Gen 49  Best = 226
# Gen 50  Best = 226
# Gen 51  Best = 226
# Gen 52  Best = 226
# Gen 53  Best = 226
# Gen 54  Best = 226
# Gen 55  Best = 226
# Gen 56  Best = 226
# Gen 57  Best = 226
# Gen 58  Best = 226
# Gen 59  Best = 226
# Gen 0  Best = 294
# Gen 1  Best = 264
# Gen 2  Best = 264
# Gen 3  Best = 258
# Gen 4  Best = 251
# Gen 5  Best = 248
# Gen 6  Best = 248
# Gen 7  Best = 248
# Gen 8  Best = 244
# Gen 9  Best = 240
# Gen 10  Best = 240
# Gen 11  Best = 240
# Gen 12  Best = 236
# Gen 13  Best = 236
# Gen 14  Best = 236
# Gen 15  Best = 236
# Gen 16  Best = 226
# Gen 17  Best = 226
# Gen 18  Best = 224
# Gen 19  Best = 224
# Gen 20  Best = 224
# Gen 21  Best = 224
# Gen 22  Best = 224
# Gen 23  Best = 224
# Gen 24  Best = 224
# Gen 25  Best = 224
# Gen 26  Best = 224
# Gen 27  Best = 224
# Gen 28  Best = 224
# Gen 29  Best = 224
# Gen 30  Best = 224
# Gen 31  Best = 224
# Gen 32  Best = 224
# Gen 33  Best = 224
# Gen 34  Best = 224
# Gen 35  Best = 224
# Gen 36  Best = 224
# Gen 37  Best = 224
# Gen 38  Best = 224
# Gen 39  Best = 224
# Gen 40  Best = 224
# Gen 41  Best = 224
# Gen 42  Best = 213
# Gen 43  Best = 213
# Gen 44  Best = 213
# Gen 45  Best = 213
# Gen 46  Best = 213
# Gen 47  Best = 209
# Gen 48  Best = 209
# Gen 49  Best = 209
# Gen 50  Best = 207
# Gen 51  Best = 207
# Gen 52  Best = 207
# Gen 53  Best = 207
# Gen 54  Best = 207
# Gen 55  Best = 207
# Gen 56  Best = 207
# Gen 57  Best = 207
# Gen 58  Best = 207
# Gen 59  Best = 207
# Gen 0  Best = 273
# Gen 1  Best = 263
# Gen 2  Best = 243
# Gen 3  Best = 243
# Gen 4  Best = 243
# Gen 5  Best = 243
# Gen 6  Best = 243
# Gen 7  Best = 243
# Gen 8  Best = 241
# Gen 9  Best = 229
# Gen 10  Best = 229
# Gen 11  Best = 229
# Gen 12  Best = 229
# Gen 13  Best = 229
# Gen 14  Best = 229
# Gen 15  Best = 229
# Gen 16  Best = 229
# Gen 17  Best = 229
# Gen 18  Best = 229
# Gen 19  Best = 229
# Gen 20  Best = 229
# Gen 21  Best = 229
# Gen 22  Best = 228
# Gen 23  Best = 228
# Gen 24  Best = 227
# Gen 25  Best = 227
# Gen 26  Best = 227
# Gen 27  Best = 227
# Gen 28  Best = 227
# Gen 29  Best = 225
# Gen 30  Best = 224
# Gen 31  Best = 224
# Gen 32  Best = 224
# Gen 33  Best = 224
# Gen 34  Best = 224
# Gen 35  Best = 222
# Gen 36  Best = 221
# Gen 37  Best = 214
# Gen 38  Best = 214
# Gen 39  Best = 214
# Gen 40  Best = 214
# Gen 41  Best = 213
# Gen 42  Best = 210
# Gen 43  Best = 210
# Gen 44  Best = 210
# Gen 45  Best = 210
# Gen 46  Best = 210
# Gen 47  Best = 210
# Gen 48  Best = 210
# Gen 49  Best = 210
# Gen 50  Best = 209
# Gen 51  Best = 208
# Gen 52  Best = 208
# Gen 53  Best = 208
# Gen 54  Best = 208
# Gen 55  Best = 208
# Gen 56  Best = 203
# Gen 57  Best = 203
# Gen 58  Best = 203
# Gen 59  Best = 203
# Gen 0  Best = 304
# Gen 1  Best = 300
# Gen 2  Best = 292
# Gen 3  Best = 290
# Gen 4  Best = 277
# Gen 5  Best = 269
# Gen 6  Best = 265
# Gen 7  Best = 265
# Gen 8  Best = 265
# Gen 9  Best = 265
# Gen 10  Best = 255
# Gen 11  Best = 246
# Gen 12  Best = 228
# Gen 13  Best = 228
# Gen 14  Best = 228
# Gen 15  Best = 228
# Gen 16  Best = 227
# Gen 17  Best = 221
# Gen 18  Best = 221
# Gen 19  Best = 215
# Gen 20  Best = 211
# Gen 21  Best = 211
# Gen 22  Best = 211
# Gen 23  Best = 211
# Gen 24  Best = 211
# Gen 25  Best = 211
# Gen 26  Best = 204
# Gen 27  Best = 204
# Gen 28  Best = 204
# Gen 29  Best = 204
# Gen 30  Best = 204
# Gen 31  Best = 202
# Gen 32  Best = 202
# Gen 33  Best = 202
# Gen 34  Best = 202
# Gen 35  Best = 202
# Gen 36  Best = 201
# Gen 37  Best = 201
# Gen 38  Best = 201
# Gen 39  Best = 201
# Gen 40  Best = 201
# Gen 41  Best = 201
# Gen 42  Best = 201
# Gen 43  Best = 201
# Gen 44  Best = 201
# Gen 45  Best = 201
# Gen 46  Best = 196
# Gen 47  Best = 196
# Gen 48  Best = 196
# Gen 49  Best = 191
# Gen 50  Best = 191
# Gen 51  Best = 191
# Gen 52  Best = 191
# Gen 53  Best = 191
# Gen 54  Best = 191
# Gen 55  Best = 189
# Gen 56  Best = 188
# Gen 57  Best = 188
# Gen 58  Best = 188
# Gen 59  Best = 188
# Gen 0 | Best 308 | Action 0
# Gen 1 | Best 308 | Action 0
# Gen 2 | Best 308 | Action 0
# Gen 3 | Best 308 | Action 0
# Gen 4 | Best 298 | Action 0
# Gen 5 | Best 298 | Action 0
# Gen 6 | Best 294 | Action 5
# Gen 7 | Best 292 | Action 0
# Gen 8 | Best 292 | Action 0
# Gen 9 | Best 290 | Action 0
# Gen 10 | Best 279 | Action 0
# Gen 11 | Best 279 | Action 0
# Gen 12 | Best 277 | Action 0
# Gen 13 | Best 277 | Action 0
# Gen 14 | Best 277 | Action 0
# Gen 15 | Best 277 | Action 1
# Gen 16 | Best 277 | Action 1
# Gen 17 | Best 277 | Action 0
# Gen 18 | Best 277 | Action 0
# Gen 19 | Best 277 | Action 0
# Gen 20 | Best 277 | Action 0
# Gen 21 | Best 277 | Action 0
# Gen 22 | Best 277 | Action 0
# Gen 23 | Best 277 | Action 0
# Gen 24 | Best 277 | Action 0
# Gen 25 | Best 277 | Action 0
# Gen 26 | Best 277 | Action 0
# Gen 27 | Best 277 | Action 0
# Gen 28 | Best 277 | Action 0
# Gen 29 | Best 272 | Action 0
# Gen 30 | Best 272 | Action 0
# Gen 31 | Best 272 | Action 3
# Gen 32 | Best 267 | Action 0
# Gen 33 | Best 267 | Action 0
# Gen 34 | Best 267 | Action 0
# Gen 35 | Best 265 | Action 0
# Gen 36 | Best 265 | Action 0
# Gen 37 | Best 265 | Action 0
# Gen 38 | Best 265 | Action 0
# Gen 39 | Best 262 | Action 0
# Gen 40 | Best 262 | Action 0
# Gen 41 | Best 262 | Action 0
# Gen 42 | Best 262 | Action 0
# Gen 43 | Best 262 | Action 5
# Gen 44 | Best 261 | Action 0
# Gen 45 | Best 261 | Action 1
# Gen 46 | Best 261 | Action 0
# Gen 47 | Best 261 | Action 0
# Gen 48 | Best 261 | Action 0
# Gen 49 | Best 261 | Action 0
# Gen 50 | Best 261 | Action 0
# Gen 51 | Best 261 | Action 0
# Gen 52 | Best 261 | Action 0
# Gen 53 | Best 257 | Action 0
# Gen 54 | Best 257 | Action 0
# Gen 55 | Best 256 | Action 0
# Gen 56 | Best 256 | Action 0
# Gen 57 | Best 256 | Action 0
# Gen 58 | Best 256 | Action 3
# Gen 59 | Best 256 | Action 0
# Gen 0 | Best 266 | Action 2
# Gen 1 | Best 243 | Action 0
# Gen 2 | Best 243 | Action 1
# Gen 3 | Best 243 | Action 2
# Gen 4 | Best 243 | Action 2
# Gen 5 | Best 241 | Action 2
# Gen 6 | Best 241 | Action 0
# Gen 7 | Best 241 | Action 2
# Gen 8 | Best 239 | Action 2
# Gen 9 | Best 239 | Action 0
# Gen 10 | Best 239 | Action 2
# Gen 11 | Best 239 | Action 2
# Gen 12 | Best 236 | Action 2
# Gen 13 | Best 236 | Action 0
# Gen 14 | Best 236 | Action 2
# Gen 15 | Best 236 | Action 2
# Gen 16 | Best 236 | Action 2
# Gen 17 | Best 236 | Action 2
# Gen 18 | Best 232 | Action 2
# Gen 19 | Best 232 | Action 0
# Gen 20 | Best 232 | Action 2
# Gen 21 | Best 231 | Action 2
# Gen 22 | Best 231 | Action 0
# Gen 23 | Best 231 | Action 2
# Gen 24 | Best 229 | Action 3
# Gen 25 | Best 226 | Action 0
# Gen 26 | Best 225 | Action 0
# Gen 27 | Best 225 | Action 5
# Gen 28 | Best 219 | Action 2
# Gen 29 | Best 219 | Action 0
# Gen 30 | Best 219 | Action 2
# Gen 31 | Best 219 | Action 2
# Gen 32 | Best 219 | Action 2
# Gen 33 | Best 219 | Action 2
# Gen 34 | Best 219 | Action 2
# Gen 35 | Best 219 | Action 2
# Gen 36 | Best 219 | Action 4
# Gen 37 | Best 218 | Action 2
# Gen 38 | Best 218 | Action 0
# Gen 39 | Best 215 | Action 2
# Gen 40 | Best 215 | Action 0
# Gen 41 | Best 215 | Action 3
# Gen 42 | Best 215 | Action 2
# Gen 43 | Best 215 | Action 2
# Gen 44 | Best 215 | Action 2
# Gen 45 | Best 215 | Action 2
# Gen 46 | Best 215 | Action 2
# Gen 47 | Best 215 | Action 4
# Gen 48 | Best 213 | Action 2
# Gen 49 | Best 213 | Action 0
# Gen 50 | Best 212 | Action 2
# Gen 51 | Best 212 | Action 0
# Gen 52 | Best 212 | Action 2
# Gen 53 | Best 212 | Action 2
# Gen 54 | Best 212 | Action 2
# Gen 55 | Best 209 | Action 2
# Gen 56 | Best 209 | Action 0
# Gen 57 | Best 209 | Action 2
# Gen 58 | Best 209 | Action 2
# Gen 59 | Best 209 | Action 2
# Gen 0 | Best 330 | Action 0
# Gen 1 | Best 330 | Action 0
# Gen 2 | Best 330 | Action 0
# Gen 3 | Best 317 | Action 0
# Gen 4 | Best 317 | Action 0
# Gen 5 | Best 317 | Action 0
# Gen 6 | Best 317 | Action 0
# Gen 7 | Best 316 | Action 0
# Gen 8 | Best 316 | Action 0
# Gen 9 | Best 315 | Action 0
# Gen 10 | Best 315 | Action 0
# Gen 11 | Best 315 | Action 0
# Gen 12 | Best 315 | Action 0
# Gen 13 | Best 311 | Action 3
# Gen 14 | Best 308 | Action 0
# Gen 15 | Best 306 | Action 0
# Gen 16 | Best 306 | Action 1
# Gen 17 | Best 306 | Action 0
# Gen 18 | Best 306 | Action 2
# Gen 19 | Best 302 | Action 0
# Gen 20 | Best 302 | Action 5
# Gen 21 | Best 302 | Action 0
# Gen 22 | Best 302 | Action 0
# Gen 23 | Best 302 | Action 0
# Gen 24 | Best 294 | Action 0
# Gen 25 | Best 294 | Action 4
# Gen 26 | Best 294 | Action 0
# Gen 27 | Best 293 | Action 0
# Gen 28 | Best 293 | Action 0
# Gen 29 | Best 293 | Action 0
# Gen 30 | Best 293 | Action 3
# Gen 31 | Best 291 | Action 0
# Gen 32 | Best 291 | Action 0
# Gen 33 | Best 291 | Action 0
# Gen 34 | Best 291 | Action 0
# Gen 35 | Best 291 | Action 0
# Gen 36 | Best 291 | Action 0
# Gen 37 | Best 281 | Action 1
# Gen 38 | Best 280 | Action 0
# Gen 39 | Best 280 | Action 0
# Gen 40 | Best 280 | Action 3
# Gen 41 | Best 280 | Action 0
# Gen 42 | Best 280 | Action 0
# Gen 43 | Best 280 | Action 5
# Gen 44 | Best 279 | Action 0
# Gen 45 | Best 279 | Action 0
# Gen 46 | Best 279 | Action 0
# Gen 47 | Best 279 | Action 0
# Gen 48 | Best 267 | Action 0
# Gen 49 | Best 267 | Action 0
# Gen 50 | Best 267 | Action 0
# Gen 51 | Best 267 | Action 3
# Gen 52 | Best 267 | Action 0
# Gen 53 | Best 267 | Action 0
# Gen 54 | Best 267 | Action 0
# Gen 55 | Best 267 | Action 0
# Gen 56 | Best 267 | Action 0
# Gen 57 | Best 267 | Action 0
# Gen 58 | Best 267 | Action 0
# Gen 59 | Best 267 | Action 0
# Gen 0 | Best 289 | Action 0
# Gen 1 | Best 289 | Action 0
# Gen 2 | Best 288 | Action 0
# Gen 3 | Best 284 | Action 0
# Gen 4 | Best 284 | Action 0
# Gen 5 | Best 283 | Action 0
# Gen 6 | Best 283 | Action 0
# Gen 7 | Best 279 | Action 0
# Gen 8 | Best 279 | Action 0
# Gen 9 | Best 279 | Action 4
# Gen 10 | Best 272 | Action 2
# Gen 11 | Best 272 | Action 5
# Gen 12 | Best 272 | Action 0
# Gen 13 | Best 272 | Action 0
# Gen 14 | Best 272 | Action 0
# Gen 15 | Best 272 | Action 0
# Gen 16 | Best 263 | Action 0
# Gen 17 | Best 263 | Action 0
# Gen 18 | Best 260 | Action 0
# Gen 19 | Best 260 | Action 0
# Gen 20 | Best 260 | Action 0
# Gen 21 | Best 260 | Action 0
# Gen 22 | Best 260 | Action 0
# Gen 23 | Best 260 | Action 2
# Gen 24 | Best 255 | Action 0
# Gen 25 | Best 255 | Action 0
# Gen 26 | Best 255 | Action 0
# Gen 27 | Best 255 | Action 0
# Gen 28 | Best 255 | Action 0
# Gen 29 | Best 255 | Action 0
# Gen 30 | Best 255 | Action 0
# Gen 31 | Best 255 | Action 0
# Gen 32 | Best 255 | Action 0
# Gen 33 | Best 255 | Action 2
# Gen 34 | Best 255 | Action 3
# Gen 35 | Best 249 | Action 0
# Gen 36 | Best 249 | Action 0
# Gen 37 | Best 247 | Action 2
# Gen 38 | Best 247 | Action 0
# Gen 39 | Best 247 | Action 0
# Gen 40 | Best 247 | Action 0
# Gen 41 | Best 247 | Action 0
# Gen 42 | Best 247 | Action 0
# Gen 43 | Best 247 | Action 0
# Gen 44 | Best 247 | Action 0
# Gen 45 | Best 247 | Action 0
# Gen 46 | Best 245 | Action 0
# Gen 47 | Best 245 | Action 0
# Gen 48 | Best 245 | Action 0
# Gen 49 | Best 245 | Action 0
# Gen 50 | Best 245 | Action 0
# Gen 51 | Best 245 | Action 0
# Gen 52 | Best 245 | Action 0
# Gen 53 | Best 245 | Action 5
# Gen 54 | Best 244 | Action 0
# Gen 55 | Best 244 | Action 1
# Gen 56 | Best 244 | Action 2
# Gen 57 | Best 243 | Action 0
# Gen 58 | Best 243 | Action 0
# Gen 59 | Best 243 | Action 0
# Gen 0 | Best 281 | Action 1
# Gen 1 | Best 281 | Action 0
# Gen 2 | Best 271 | Action 1
# Gen 3 | Best 271 | Action 0
# Gen 4 | Best 268 | Action 1
# Gen 5 | Best 268 | Action 0
# Gen 6 | Best 268 | Action 1
# Gen 7 | Best 268 | Action 1
# Gen 8 | Best 268 | Action 1
# Gen 9 | Best 268 | Action 1
# Gen 10 | Best 268 | Action 0
# Gen 11 | Best 268 | Action 1
# Gen 12 | Best 268 | Action 1
# Gen 13 | Best 268 | Action 1
# Gen 14 | Best 268 | Action 1
# Gen 15 | Best 268 | Action 1
# Gen 16 | Best 268 | Action 1
# Gen 17 | Best 268 | Action 4
# Gen 18 | Best 268 | Action 1
# Gen 19 | Best 268 | Action 1
# Gen 20 | Best 268 | Action 1
# Gen 21 | Best 268 | Action 1
# Gen 22 | Best 268 | Action 1
# Gen 23 | Best 268 | Action 1
# Gen 24 | Best 268 | Action 1
# Gen 25 | Best 268 | Action 1
# Gen 26 | Best 268 | Action 1
# Gen 27 | Best 268 | Action 1
# Gen 28 | Best 268 | Action 1
# Gen 29 | Best 268 | Action 1
# Gen 30 | Best 268 | Action 1
# Gen 31 | Best 268 | Action 1
# Gen 32 | Best 268 | Action 4
# Gen 33 | Best 268 | Action 1
# Gen 34 | Best 268 | Action 1
# Gen 35 | Best 268 | Action 1
# Gen 36 | Best 268 | Action 1
# Gen 37 | Best 268 | Action 1
# Gen 38 | Best 268 | Action 1
# Gen 39 | Best 268 | Action 1
# Gen 40 | Best 268 | Action 1
# Gen 41 | Best 268 | Action 4
# Gen 42 | Best 265 | Action 1
# Gen 43 | Best 265 | Action 0
# Gen 44 | Best 265 | Action 1
# Gen 45 | Best 265 | Action 1
# Gen 46 | Best 265 | Action 1
# Gen 47 | Best 265 | Action 1
# Gen 48 | Best 265 | Action 1
# Gen 49 | Best 265 | Action 1
# Gen 50 | Best 265 | Action 1
# Gen 51 | Best 265 | Action 1
# Gen 52 | Best 265 | Action 1
# Gen 53 | Best 265 | Action 1
# Gen 54 | Best 265 | Action 1
# Gen 55 | Best 265 | Action 1
# Gen 56 | Best 265 | Action 1
# Gen 57 | Best 265 | Action 1
# Gen 58 | Best 265 | Action 1
# Gen 59 | Best 265 | Action 1

# %% [markdown]
# ##🧪اجرای نهایی
